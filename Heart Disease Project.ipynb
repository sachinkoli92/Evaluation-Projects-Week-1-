# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
hd=pd.read_csv('heartdisease.csv',na_values='?')

# %%
hd
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca  thal  num
# 0      3.0  0.0   6.0    0
# ...

# %% [markdown]
# 1. sex is denoted 0 as female 1 as male.
# 2. cp= chest pain type 1.typical angina value, 2. atypical angina value, 3. non-anginal pain value, 4. asymptomatic.
# 3. trestbps is the resting blood pressure.
# 4. chol is cholestrol.
# 5. fbs is fasting blood sugar 1 is true,0 is false.
# 6. thalach is maximum heart rate achieved.
# 7. exang is exercise induced angina (1 = yes 0 = no).
# 8. restcg is  resting electrocardiographic results : Value 0: normal,Value 1: having ST-T wave abnormality,Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria.
# 9. oldpeak is ST depression induced by exercise relative to rest.
# 10. slope is the slope of the peak exercise ST segment:- Value 1: upsloping, Value 2: flat, Value 3: downsloping.
# 11. ca is number of major vessels (0-3) colored by flourosopy.
# 12 thal:3 = normal; 6 = fixed defect; 7 = reversable defect.
# 13. num is target variable that tells diagnosis of heart disease (angiographic disease status).

# %% [markdown]
# # Exploratory Data Analysis

# %%
hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    float64
#  1   sex       303 non-null    float64
#  2   cp        303 non-null    float64
#  3   trestbps  303 non-null    float64
#  4   chol      303 non-null    float64
#  5   fbs       303 non-null    float64
#  6   restecg   303 non-null    float64
#  7   thalach   303 non-null    float64
#  8   exang     303 non-null    float64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    float64
#  11  ca        299 non-null    float64
#  12  thal      301 non-null    float64
#  13  num       303 non-null    int64
# dtypes: float64(13), int64(1)
# memory usage: 33.3 KB

# %% [markdown]
# ✏ In this the target varible is num

# %%
hd.shape
# Out:
# (303, 14)

# %%
hd.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# num         0
# dtype: int64

# %% [markdown]
# Features ca and thal has null values

# %%
hd.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %% [markdown]
# 1. In age it shows min age is 29 and max age is 77
# 2. In col feature std is very high
# 3. trestbps,chol,thalach,oldpeak  in these features there is a difference between 75% and max by which we know that there must be outliers.
# 4. After analysing in most of the features the mean of them is greater than  the median so the data is skewed.

# %%
hd.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.097542  0.104139  0.284946  0.208950  0.118530
# sex      -0.097542  1.000000  0.010084 -0.064456 -0.199915  0.047862
# cp        0.104139  0.010084  1.000000 -0.036077  0.072319 -0.039975
# trestbps  0.284946 -0.064456 -0.036077  1.000000  0.130120  0.175340
# chol      0.208950 -0.199915  0.072319  0.130120  1.000000  0.009841
# fbs       0.118530  0.047862 -0.039975  0.175340  0.009841  1.000000
# restecg   0.148868  0.021647  0.067505  0.146560  0.171043  0.069564
# thalach  -0.393806 -0.048663 -0.334422 -0.045351 -0.003432 -0.007854
# exang     0.091661  0.146201  0.384060  0.064762  0.061310  0.025665
# oldpeak   0.203805  0.102173  0.202277  0.189171  0.046564  0.005747
# slope     0.161770  0.037533  0.152050  0.117382 -0.004062  0.059894
# ca        0.362605  0.093185  0.233214  0.098773  0.119000  0.145478
# thal      0.127389  0.380936  0.265246  0.133554  0.014214  0.071358
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(hd.corr(),cmap='twilight')

# %% [markdown]
# thalach has a negative correlation with num(target variable),age,sex,cp,trestbps,chol,fbs,restecg,exang,oldpeak,slope,ca,thal.

# %% [markdown]
# # Visualization

# %%
for g in hd.describe().columns:
    sns.distplot(hd[g].dropna())
    plt.show()

# %% [markdown]
# Observations:
# 1. Age, trestbps,chol,thalach is normally distributed.
# 2. Sex is a categorical variable with most values having 1.
# 3. cp,oldpeak  is left skewed.

# %%
for i in hd. columns:
    if hd.dtypes.loc[i]=='float64':
        hd[i].plot.hist()
        plt.title(i)
        plt.show()

# %%
# bivariate analysis

# %%
plt.figure(figsize=(30,10))
sns.barplot(x='age',y='num',data=hd)

# %% [markdown]
# we can see that as the age is increasing there is a higher chance of having a heart disease.

# %%
sns.barplot(x='sex',y='chol',hue='num',data=hd)

# %% [markdown]
# Female  have a higher cholestrol than male which may lead in heart disease.

# %%
sns.barplot(x='sex',y='cp',hue='num',data=hd)

# %% [markdown]
# cp=chest pain. 4.0= asymptomatic.
# it shows in chest  pain most of them are asymptomatic either it male or female.

# %%
sns.barplot(x='restecg',y='num',data=hd)

# %% [markdown]
# An ST-T wave abnormality might be indicative of a heart disease.

# %%
sns.barplot(x='exang',y='num',data=hd)

# %% [markdown]
# Patients who are  experiencing angina during excerise  are more prone of heart disease

# %%
sns.barplot(x='slope',y='num',data=hd)

# %%
hd.plot.kde(x='num',y='trestbps')

# %%
# People  having  trestbps  between 100-160 showing higher rates of having heart disease.

# %%
for i in hd.columns:
        sns.boxplot(hd[i])
        plt.show()

# %% [markdown]
# Note: trestbps,chol,oldpeak are having  outliers which  we will remove before performing model.

# %%
hd.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# num         0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
si=SimpleImputer(strategy='median')

# %%
for i in hd.columns:
    if hd.isna().sum().loc[i]!=0:
        hd[i]=si.fit_transform(hd[i].values.reshape(-1,1))

# %%
hd.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
hd
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca  thal  num
# 0      3.0  0.0   6.0    0
# ...

# %%
hd=pd.get_dummies(hd,columns=['sex','cp','fbs','restecg','exang','slope','ca','thal'],drop_first=True)

# %%
hd
# Out:
#       age  trestbps   chol  thalach  oldpeak  num  sex_1.0  cp_2.0  cp_3.0  \
# 0    63.0     145.0  233.0    150.0      2.3    0        1       0       0
# 1    67.0     160.0  286.0    108.0      1.5    2        1       0       0
# 2    67.0     120.0  229.0    129.0      2.6    1        1       0       0
# 3    37.0     130.0  250.0    187.0      3.5    0        1       0       1
# 4    41.0     130.0  204.0    172.0      1.4    0        0       1       0
# ..    ...       ...    ...      ...      ...  ...      ...     ...     ...
# 298  45.0     110.0  264.0    132.0      1.2    1        1       0       0
# 299  68.0     144.0  193.0    141.0      3.4    2        1       0       0
# 300  57.0     130.0  131.0    115.0      1.2    3        1       0       0
# 301  57.0     130.0  236.0    174.0      0.0    1        0       1       0
# 302  38.0     138.0  175.0    173.0      0.0    0        1       0       1
#
# ...

# %%
#checking the skewness of the  data
hd.skew()
# Out:
# age           -0.209060
# trestbps       0.706035
# chol           1.135503
# thalach       -0.537449
# oldpeak        1.269720
# num            1.058496
# sex_1.0       -0.774935
# cp_2.0         1.813882
# cp_3.0         0.963719
# cp_4.0         0.099625
# fbs_1.0        1.986652
# restecg_1.0    8.572643
# restecg_2.0    0.046447
# exang_1.0      0.742532
# slope_2.0      0.153013
# slope_3.0      3.408510
# ca_1.0         1.397846
# ca_2.0         2.273366
# ca_3.0         3.513224
# thal_6.0       3.746372
# thal_7.0       0.470065
# dtype: float64

# %%
#Treating skewness using log transform
a=['age','trestbps','chol','thalach','oldpeak']
for i in a:
    if hd.skew().loc[i]>0.55:
        hd[i]=np.log1p(hd[i])

# %%
hd.skew()
# Out:
# age           -0.209060
# trestbps       0.281940
# chol           0.081733
# thalach       -0.537449
# oldpeak        0.396825
# num            1.058496
# sex_1.0       -0.774935
# cp_2.0         1.813882
# cp_3.0         0.963719
# cp_4.0         0.099625
# fbs_1.0        1.986652
# restecg_1.0    8.572643
# restecg_2.0    0.046447
# exang_1.0      0.742532
# slope_2.0      0.153013
# slope_3.0      3.408510
# ca_1.0         1.397846
# ca_2.0         2.273366
# ca_3.0         3.513224
# thal_6.0       3.746372
# thal_7.0       0.470065
# dtype: float64

# %%
hd
# Out:
#       age  trestbps      chol  thalach   oldpeak  num  sex_1.0  cp_2.0  \
# 0    63.0  4.983607  5.455321    150.0  1.193922    0        1       0
# 1    67.0  5.081404  5.659482    108.0  0.916291    2        1       0
# 2    67.0  4.795791  5.438079    129.0  1.280934    1        1       0
# 3    37.0  4.875197  5.525453    187.0  1.504077    0        1       0
# 4    41.0  4.875197  5.323010    172.0  0.875469    0        0       1
# ..    ...       ...       ...      ...       ...  ...      ...     ...
# 298  45.0  4.709530  5.579730    132.0  0.788457    1        1       0
# 299  68.0  4.976734  5.267858    141.0  1.481605    2        1       0
# 300  57.0  4.875197  4.882802    115.0  0.788457    3        1       0
# 301  57.0  4.875197  5.468060    174.0  0.000000    1        0       1
# 302  38.0  4.934474  5.170484    173.0  0.000000    0        1       0
#
#      cp_3.0  cp_4.0  ...  restecg_1.0  restecg_2.0  exang_1.0  slope_2.0  \
# ...

# %%
#Removing outliers using Z score

from scipy.stats import zscore

# %%
z=np.abs(zscore(hd))

hdp=hd[(z<3).all(axis=1)]
print('Shape before removing outliers: ',hd.shape)
print('Shape after removing outliers: ',hdp.shape)
# Out:
# Shape before removing outliers:  (303, 21)
# Shape after removing outliers:  (243, 21)

# %%
hdp
# Out:
#       age  trestbps      chol  thalach   oldpeak  num  sex_1.0  cp_2.0  \
# 2    67.0  4.795791  5.438079    129.0  1.280934    1        1       0
# 4    41.0  4.875197  5.323010    172.0  0.875469    0        0       1
# 5    56.0  4.795791  5.468060    178.0  0.587787    0        1       1
# 7    57.0  4.795791  5.872118    163.0  0.470004    0        0       0
# 8    63.0  4.875197  5.541264    147.0  0.875469    2        1       0
# ..    ...       ...       ...      ...       ...  ...      ...     ...
# 297  57.0  4.948760  5.488938    123.0  0.182322    1        0       0
# 298  45.0  4.709530  5.579730    132.0  0.788457    1        1       0
# 299  68.0  4.976734  5.267858    141.0  1.481605    2        1       0
# 301  57.0  4.875197  5.468060    174.0  0.000000    1        0       1
# 302  38.0  4.934474  5.170484    173.0  0.000000    0        1       0
#
#      cp_3.0  cp_4.0  ...  restecg_1.0  restecg_2.0  exang_1.0  slope_2.0  \
# ...

# %%
x=hdp.drop(['num'],axis=1)
x
# Out:
#       age  trestbps      chol  thalach   oldpeak  sex_1.0  cp_2.0  cp_3.0  \
# 2    67.0  4.795791  5.438079    129.0  1.280934        1       0       0
# 4    41.0  4.875197  5.323010    172.0  0.875469        0       1       0
# 5    56.0  4.795791  5.468060    178.0  0.587787        1       1       0
# 7    57.0  4.795791  5.872118    163.0  0.470004        0       0       0
# 8    63.0  4.875197  5.541264    147.0  0.875469        1       0       0
# ..    ...       ...       ...      ...       ...      ...     ...     ...
# 297  57.0  4.948760  5.488938    123.0  0.182322        0       0       0
# 298  45.0  4.709530  5.579730    132.0  0.788457        1       0       0
# 299  68.0  4.976734  5.267858    141.0  1.481605        1       0       0
# 301  57.0  4.875197  5.468060    174.0  0.000000        0       1       0
# 302  38.0  4.934474  5.170484    173.0  0.000000        1       0       1
#
#      cp_4.0  fbs_1.0  restecg_1.0  restecg_2.0  exang_1.0  slope_2.0  \
# ...

# %%
y=hdp['num']
y
# Out:
# 2      1
# 4      0
# 5      0
# 7      0
# 8      2
#       ..
# 297    1
# 298    1
# 299    2
# 301    1
# 302    0
# Name: num, Length: 243, dtype: int64

# %%
#Scaling the data.
from sklearn.preprocessing import StandardScaler

sc=StandardScaler()
list=['age','trestbps','chol','thalach','oldpeak']
for i in list:
    x[i]=sc.fit_transform(x[i].values.reshape(-1,1))

# %%
x
# Out:
#           age  trestbps      chol   thalach   oldpeak  sex_1.0  cp_2.0  \
# 2    1.483722 -0.574270 -0.312609 -1.117579  1.645811        1       0
# 4   -1.400633  0.056050 -0.931879  0.904514  0.810214        0       1
# 5    0.263418 -0.574270 -0.151261  1.186666  0.217349        1       1
# 7    0.374354 -0.574270  2.023262  0.481285 -0.025382        0       0
# 8    1.039975  0.056050  0.242699 -0.271122  0.810214        1       0
# ..        ...       ...       ...       ...       ...      ...     ...
# 297  0.374354  0.639980 -0.038904 -1.399732 -0.618247        0       0
# 298 -0.956887 -1.258993  0.449713 -0.976503  0.630898        1       0
# 299  1.594659  0.862032 -1.228691 -0.553274  2.059360        1       0
# 301  0.374354  0.056050 -0.151261  0.998564 -0.993982        0       1
# 302 -1.733444  0.526580 -1.752731  0.951539 -0.993982        1       0
#
#      cp_3.0  cp_4.0  fbs_1.0  restecg_1.0  restecg_2.0  exang_1.0  slope_2.0  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
a=[DecisionTreeClassifier(),SVC(),KNeighborsClassifier(),AdaBoostClassifier()]
for j in a:
    max_r_score=0
    print('for the algorithm :',j)
    for i in range(33,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.20)
        j.fit(x_train,y_train)
        pred=j.predict(x_test)
        score=j.score(x_train,y_train)
        accuracy=accuracy_score(pred,y_test)
        print('accuracy score corresponding to random state',i,'is: ',accuracy)
        if accuracy>max_r_score:
            max_r_score=accuracy
            final=i
    print('\n')
    print('Max accuracy score corresponding to: ', final,'is: ',max_r_score)
    print('✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦')
    print('\n')
# Out:
# for the algorithm : DecisionTreeClassifier()
# accuracy score corresponding to random state 33 is:  0.5510204081632653
# accuracy score corresponding to random state 34 is:  0.6122448979591837
# accuracy score corresponding to random state 35 is:  0.5510204081632653
# accuracy score corresponding to random state 36 is:  0.6122448979591837
# accuracy score corresponding to random state 37 is:  0.40816326530612246
# accuracy score corresponding to random state 38 is:  0.5714285714285714
# accuracy score corresponding to random state 39 is:  0.5306122448979592
# accuracy score corresponding to random state 40 is:  0.40816326530612246
# accuracy score corresponding to random state 41 is:  0.4897959183673469
# accuracy score corresponding to random state 42 is:  0.5714285714285714
# accuracy score corresponding to random state 43 is:  0.4897959183673469
# accuracy score corresponding to random state 44 is:  0.5306122448979592
# ...

# %% [raw]
# K Neighbors Classifier is working best among all models at random state=35.

# %%
#Using ensemble technique to boost our score
import numpy as np
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=52)
rf=RandomForestClassifier(criterion='gini',n_estimators=20,random_state=52)
rf.fit(x_train,y_train)
print('Score of random forest is:',rf.score(x_train,y_train))
predict=rf.predict(x_test)
print('Accuracy Score: ',accuracy_score(y_test,predict))
print('Confusion matrix: ',confusion_matrix(y_test,predict))
print('Classification report:',classification_report(y_test,predict))
# Out:
# Score of random forest is: 0.9945054945054945
# Accuracy Score:  0.6721311475409836
# Confusion matrix:  [[32  2  0  0]
#  [ 7  6  1  1]
#  [ 1  2  1  2]
#  [ 2  0  2  2]]
# Classification report:               precision    recall  f1-score   support
#
#            0       0.76      0.94      0.84        34
#            1       0.60      0.40      0.48        15
#            2       0.25      0.17      0.20         6
#            3       0.40      0.33      0.36         6
#
#     accuracy                           0.67        61
#    macro avg       0.50      0.46      0.47        61
# weighted avg       0.64      0.67      0.64        61

# %%
from sklearn.model_selection import GridSearchCV
knn=KNeighborsClassifier()
parameters={
           'weights':['uniform','distance',]}
cv=GridSearchCV(knn,parameters)
cv.fit(x,y)
cv.best_params_
# Out:
# {'weights': 'uniform'}

# %%
knn=KNeighborsClassifier(n_neighbors=5,weights='uniform')
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=35,test_size=.20)
knn.fit(x_train,y_train)
pred=knn.predict(x_test)
score=knn.score(x_train,y_train)
accuracy=accuracy_score(pred,y_test)
print('Accuracy score: ',accuracy)
print('Confusion Matrix:',confusion_matrix(pred,y_test))
print('Classification report:',classification_report(pred,y_test))
print('✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦')
# Out:
# Accuracy score:  0.8163265306122449
# Confusion Matrix: [[33  4  0  0]
#  [ 0  4  3  2]
#  [ 0  0  1  0]
#  [ 0  0  0  2]]
# Classification report:               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94        37
#            1       0.50      0.44      0.47         9
#            2       0.25      1.00      0.40         1
#            3       0.50      1.00      0.67         2
#
#     accuracy                           0.82        49
#    macro avg       0.56      0.83      0.62        49
# weighted avg       0.87      0.82      0.83        49
#
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦

# %%
#saving the model using joblib
import joblib
joblib.dump(knn,'HeartDisease.pkl')
# Out:
# ['HeartDisease.pkl']
