# %%
#Loading Necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import roc_curve,roc_auc_score,auc

#Importing the Model Libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

#Importing Boosting Models
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier,BaggingClassifier

#Importing Error Metrics
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,roc_auc_score,roc_curve,auc

# %%
#Loading preprocessing pipline functions
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer
from scipy.stats import zscore

# %%
hra=pd.read_csv('hr_analytics.csv')

# %%
hra
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %% [markdown]
# ✏ In this the target varible is Attrition

# %% [markdown]
# # Exploratory Data Analysis

# %%
hra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %% [markdown]
# Mostly columns are of integer type excepy Attrition, Business Travel, Department,EducationField,Gender,JobRole,MaritalStatus,Over18,OverTime.

# %%
hra.shape
# Out:
# (1470, 35)

# %%
#Checking of null values in the data

hra.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
# we see there are no null values in above whole data.

# %%
hra['Gender']
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3       Female
# 4         Male
#          ...
# 1465      Male
# 1466      Male
# 1467      Male
# 1468      Male
# 1469      Male
# Name: Gender, Length: 1470, dtype: object

# %%
sns.countplot(hra['Attrition'])
print(hra['Attrition'].value_counts())
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
for i in hra.columns:
    if hra.dtypes.loc[i]=='object':
        print(hra[i].value_counts())
        sns.countplot(hra[i])
        plt.xticks(rotation=30)
        plt.show()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
# Male      882
# Female    588
# Name: Gender, dtype: int64
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64
# Y    1470
# Name: Over18, dtype: int64
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %% [markdown]
# Observations:
#
# 1. In travel there are a huge number of employees who travel rarely for the work.
# 2. In department most of the employees in the data are in the research and development department
# 3. In EducationField there are six education sectors as Life Sciences, Other,Medical,Marketing, Technical Degree,Human Resources. and out of all six maximum persons are from Life Science and minimum are Human Resources.
# 4. In Gender the company has more male employees than female
# 5. In JobRole they are button down in nine ways and the most employees are from Sales Executive.
# 6. In Marital Status we observe three marital status as single, Married and Divorced And Married employee are more in number.
# 7. Over18 is a feature with constant entry for all employees as all the employees are over 18. this column will not help in the Machine Learning.
# 8. Overtime is a feature in which we can observe that employees are not much interested in doing overtime.

# %%
for i in hra. columns:
    if hra.dtypes.loc[i]=='int64':
        hra[i].plot.hist()
        plt.title(i)
        plt.show()

# %% [markdown]
# Observations:
#
# 1. There are several features i.e. DistanceFromHome,JobSatisfaction,MonthlyRate,TotalWorkingYears,PercenSalaryHike,TotalWorkingYears,YearsAtCompany,YearsInCurrentRole etc, are righly skewed. which we have to deal prior to our model fitting.
#
#
# 2. EmployeeNumber and StandardHours are such features which are almost alike to all employees. So these features has nothing to contribute in the target variable.
#
# ================================================================================================================================

# %% [markdown]
# Note: Attrition is a categorical data with yes and no as the entries and for comparing it with other variabless we need to convert attrition categorical data into binary data using Label Encoder.

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
hra['Attrition']=le.fit_transform(hra['Attrition'].astype(str))

# %%
hra
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %% [markdown]
# #Using Attrition as fixed variable comparing with other variables.

# %%
sns.barplot(x='BusinessTravel',y='Attrition',data=hra)

# %% [markdown]
# Number of employees who travel frequently with a higher Attrition Rate.

# %%
sns.barplot(x='Department',y='Attrition',data=hra)

# %% [markdown]
# Sales Department  have a slight higher attrition rate than Human Resources and R&D has the lowest among of all three department.

# %%
sns.barplot(x='MaritalStatus',y='Attrition',data=hra)

# %% [markdown]
# No of employees who are single are the one with the higher attrition rate among married and Divorced

# %%
sns.barplot(x='OverTime',y='Attrition',data=hra)

# %% [markdown]
# Employees who are working over time can leave the company as they are having higher attrition rate.

# %%
sns.barplot(x='WorkLifeBalance',y='Attrition',data=hra)

# %% [markdown]
# Employee who is having low work life balance lean to have higher attrition rate.

# %%
sns.barplot(x='YearsWithCurrManager',y='Attrition',data=hra)

# %% [markdown]
# No such change can been seen either a employee is with current manager or not they are having a high attrition rate.

# %%
#Statistics analysis

hra.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810     0.161224   802.485714          9.192517     2.912925
# std       9.135373     0.367863   403.509100          8.106864     1.024165
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     0.000000   465.000000          2.000000     2.000000
# 50%      36.000000     0.000000   802.000000          7.000000     3.000000
# 75%      43.000000     0.000000  1157.000000         14.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769    65.891156
# std              0.0      602.024335                 1.093082    20.329428
# min              1.0        1.000000                 1.000000    30.000000
# 25%              1.0      491.250000                 2.000000    48.000000
# 50%              1.0     1020.500000                 3.000000    66.000000
# 75%              1.0     1555.750000                 4.000000    83.750000
# max              1.0     2068.000000                 4.000000   100.000000
#
#        JobInvolvement  ...  RelationshipSatisfaction  StandardHours  \
# count     1470.000000  ...               1470.000000         1470.0
# mean         2.729932  ...                  2.712245           80.0
# std          0.711561  ...                  1.081209            0.0
# min          1.000000  ...                  1.000000           80.0
# 25%          2.000000  ...                  2.000000           80.0
# 50%          3.000000  ...                  3.000000           80.0
# 75%          3.000000  ...                  4.000000           80.0
# max          4.000000  ...                  4.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1470.000000        1470.000000            1470.000000
# mean           0.793878          11.279592               2.799320
# std            0.852077           7.780782               1.289271
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1470.000000           1470.000000
# mean                  2.187755              4.123129
# std                   3.222430              3.568136
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 27 columns]

# %% [markdown]
# After we are describing no of columns we are not visible in the above table. To get a more clear view  of it  lets now draw distplot and boxplot which will tell us skewness and oultiers of the data we have.

# %%
for i in hra.columns:
    if hra.dtypes.loc[i]=='int64':
        sns.distplot(hra[i])
        plt.title(i)
        plt.show()

# %% [markdown]
# Skewed columns:DistanceFromHome, MonthlyIncome, NumCompaniesWorked, PercentSalaryHike, TotalWorkingHours, YearsSinceLastPromotion, YearsAtCompany these features are skewed.

# %%
for i in hra.columns:
    if hra.dtypes.loc[i]=='int64':
        sns.boxplot(hra[i].dropna())
        plt.title(i)
        plt.show()

# %% [markdown]
# Found Outliers in : MonthlyIncome, PercentSalaryHike, TotalWorkingHours, YearsAtCompany, YearsInCurrrentRole, YearsSinceLastPromotion

# %%
# Applying LabelEncoder to convert categorical data

# %%
# from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in hra.columns:
    if hra.dtypes.loc[i]=='object':
        hra[i]=le.fit_transform(hra[i].astype(str))

# %%
hra
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
#       Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0             2               1              1               1  ...
# 1             1               1              1               2  ...
# 2             2               4              1               4  ...
# 3             4               1              1               5  ...
# 4             1               3              1               7  ...
# ...         ...             ...            ...             ...  ...
# 1465          2               3              1            2061  ...
# 1466          1               3              1            2062  ...
# 1467          3               1              1            2064  ...
# 1468          3               3              1            2065  ...
# 1469          3               3              1            2068  ...
#
#       RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                            1             80                 0
# 1                            4             80                 1
# 2                            2             80                 0
# 3                            3             80                 0
# 4                            4             80                 1
# ...                        ...            ...               ...
# 1465                         3             80                 1
# 1466                         1             80                 1
# 1467                         2             80                 1
# 1468                         4             80                 0
# 1469                         1             80                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     8                      0                1
# 1                    10                      3                3
# 2                     7                      3                3
# 3                     8                      3                3
# 4                     6                      3                3
# ...                 ...                    ...              ...
# 1465                 17                      3                3
# 1466                  9                      5                3
# 1467                  6                      0                3
# 1468                 17                      3                2
# 1469                  6                      3                4
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                  6                   4                        0
# 1                 10                   7                        1
# 2                  0                   0                        0
# 3                  8                   7                        3
# 4                  2                   2                        2
# ...              ...                 ...                      ...
# 1465               5                   2                        0
# 1466               7                   7                        1
# 1467               6                   2                        0
# 1468               9                   6                        0
# 1469               4                   3                        1
#
#       YearsWithCurrManager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
# ...                    ...
# 1465                     3
# 1466                     7
# 1467                     3
# 1468                     8
# 1469                     2
#
# [1470 rows x 35 columns]

# %% [markdown]
# Dropping the features with constant entry i.e. Over18, StandardHours, EmployeeCount.

# %%
hra.drop(['Over18','StandardHours','EmployeeCount'],axis=1,inplace=True)

# %%
hra
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
#       Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  ...  \
# 0             2               1               1                        2  ...
# 1             1               1               2                        3  ...
# 2             2               4               4                        4  ...
# 3             4               1               5                        4  ...
# 4             1               3               7                        1  ...
# ...         ...             ...             ...                      ...  ...
# 1465          2               3            2061                        3  ...
# 1466          1               3            2062                        4  ...
# 1467          3               1            2064                        2  ...
# 1468          3               3            2065                        4  ...
# 1469          3               3            2068                        2  ...
#
#       PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                     3                         1                 0
# 1                     4                         4                 1
# 2                     3                         2                 0
# 3                     3                         3                 0
# 4                     3                         4                 1
# ...                 ...                       ...               ...
# 1465                  3                         3                 1
# 1466                  3                         1                 1
# 1467                  4                         2                 1
# 1468                  3                         4                 0
# 1469                  3                         1                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     8                      0                1
# 1                    10                      3                3
# 2                     7                      3                3
# 3                     8                      3                3
# 4                     6                      3                3
# ...                 ...                    ...              ...
# 1465                 17                      3                3
# 1466                  9                      5                3
# 1467                  6                      0                3
# 1468                 17                      3                2
# 1469                  6                      3                4
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                  6                   4                        0
# 1                 10                   7                        1
# 2                  0                   0                        0
# 3                  8                   7                        3
# 4                  2                   2                        2
# ...              ...                 ...                      ...
# 1465               5                   2                        0
# 1466               7                   7                        1
# 1467               6                   2                        0
# 1468               9                   6                        0
# 1469               4                   3                        1
#
#       YearsWithCurrManager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
# ...                    ...
# 1465                     3
# 1466                     7
# 1467                     3
# 1468                     8
# 1469                     2
#
# [1470 rows x 32 columns]

# %%
hra.corr()
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159205        0.024751   0.010661
# Attrition                -0.159205   1.000000        0.000074  -0.056652
# BusinessTravel            0.024751   0.000074        1.000000  -0.004086
# DailyRate                 0.010661  -0.056652       -0.004086   1.000000
# Department               -0.031882   0.063991       -0.009044   0.007109
# DistanceFromHome         -0.001686   0.077924       -0.024469  -0.004985
# Education                 0.208034  -0.031373        0.000757  -0.016806
# EducationField           -0.040873   0.026846        0.023724   0.037709
# EmployeeNumber           -0.010145  -0.010577       -0.015578  -0.050990
# EnvironmentSatisfaction   0.010146  -0.103369        0.004174   0.018355
# Gender                   -0.036311   0.029453       -0.032981  -0.011716
# HourlyRate                0.024287  -0.006846        0.026528   0.023381
# JobInvolvement            0.029820  -0.130016        0.039062   0.046135
# JobLevel                  0.509604  -0.169105        0.019311   0.002966
# JobRole                  -0.122427   0.067151        0.002724  -0.009472
# JobSatisfaction          -0.004892  -0.103481       -0.033962   0.030571
# MaritalStatus            -0.095029   0.162070        0.024001  -0.069586
# MonthlyIncome             0.497855  -0.159840        0.034319   0.007707
# MonthlyRate               0.028051   0.015170       -0.014107  -0.032182
# NumCompaniesWorked        0.299635   0.043494        0.020875   0.038153
# OverTime                  0.028062   0.246118        0.016543   0.009135
# PercentSalaryHike         0.003634  -0.013478       -0.029377   0.022704
# PerformanceRating         0.001904   0.002889       -0.026341   0.000473
# RelationshipSatisfaction  0.053535  -0.045872       -0.035986   0.007846
# StockOptionLevel          0.037510  -0.137145       -0.016727   0.042143
# TotalWorkingYears         0.680381  -0.171063        0.034226   0.014515
# TrainingTimesLastYear    -0.019621  -0.059478        0.015240   0.002453
# WorkLifeBalance          -0.021490  -0.063939       -0.011256  -0.037848
# YearsAtCompany            0.311309  -0.134392       -0.014575  -0.034055
# YearsInCurrentRole        0.212901  -0.160545       -0.011497   0.009932
# YearsSinceLastPromotion   0.216513  -0.033019       -0.032591  -0.033229
# YearsWithCurrManager      0.202089  -0.156199       -0.022636  -0.026363
#
#                           Department  DistanceFromHome  Education  \
# Age                        -0.031882         -0.001686   0.208034
# Attrition                   0.063991          0.077924  -0.031373
# BusinessTravel             -0.009044         -0.024469   0.000757
# DailyRate                   0.007109         -0.004985  -0.016806
# Department                  1.000000          0.017225   0.007996
# DistanceFromHome            0.017225          1.000000   0.021042
# Education                   0.007996          0.021042   1.000000
# EducationField              0.013720          0.002013  -0.039592
# EmployeeNumber             -0.010895          0.032916   0.042070
# EnvironmentSatisfaction    -0.019395         -0.016075  -0.027128
# Gender                     -0.041583         -0.001851  -0.016547
# HourlyRate                 -0.004144          0.031131   0.016775
# JobInvolvement             -0.024586          0.008783   0.042438
# JobLevel                    0.101963          0.005303   0.101589
# JobRole                     0.662431         -0.001015   0.004236
# JobSatisfaction             0.021001         -0.003669  -0.011296
# MaritalStatus               0.056073         -0.014437   0.004053
# MonthlyIncome               0.053130         -0.017014   0.094961
# MonthlyRate                 0.023642          0.027473  -0.026084
# NumCompaniesWorked         -0.035882         -0.029251   0.126317
# OverTime                    0.007481          0.025514  -0.020322
# PercentSalaryHike          -0.007840          0.040235  -0.011111
# PerformanceRating          -0.024604          0.027110  -0.024539
# RelationshipSatisfaction   -0.022414          0.006557  -0.009118
# StockOptionLevel           -0.012193          0.044872   0.018422
# TotalWorkingYears          -0.015762          0.004628   0.148280
# TrainingTimesLastYear       0.036875         -0.036942  -0.025100
# WorkLifeBalance             0.026383         -0.026556   0.009819
# YearsAtCompany              0.022920          0.009508   0.069114
# YearsInCurrentRole          0.056315          0.018845   0.060236
# YearsSinceLastPromotion     0.040061          0.010029   0.054254
# YearsWithCurrManager        0.034282          0.014406   0.069065
#
#                           EducationField  EmployeeNumber  \
# Age                            -0.040873       -0.010145
# Attrition                       0.026846       -0.010577
# BusinessTravel                  0.023724       -0.015578
# DailyRate                       0.037709       -0.050990
# Department                      0.013720       -0.010895
# DistanceFromHome                0.002013        0.032916
# Education                      -0.039592        0.042070
# EducationField                  1.000000       -0.002516
# EmployeeNumber                 -0.002516        1.000000
# EnvironmentSatisfaction         0.043163        0.017621
# Gender                         -0.002504        0.022556
# HourlyRate                     -0.021941        0.035179
# JobInvolvement                 -0.002655       -0.006888
# JobLevel                       -0.044933       -0.018519
# JobRole                         0.015599       -0.010336
# JobSatisfaction                -0.034401       -0.046247
# MaritalStatus                   0.014420       -0.008155
# MonthlyIncome                  -0.041070       -0.014829
# MonthlyRate                    -0.027182        0.012648
# NumCompaniesWorked             -0.008663       -0.001251
# OverTime                        0.002259       -0.024037
# PercentSalaryHike              -0.011214       -0.012944
# PerformanceRating              -0.005614       -0.020359
# RelationshipSatisfaction       -0.004378       -0.069861
# StockOptionLevel               -0.016185        0.062227
# TotalWorkingYears              -0.027848       -0.014365
# TrainingTimesLastYear           0.049195        0.023603
# WorkLifeBalance                 0.041191        0.010309
# YearsAtCompany                 -0.018692       -0.011240
# YearsInCurrentRole             -0.010506       -0.008416
# YearsSinceLastPromotion         0.002326       -0.009019
# YearsWithCurrManager           -0.004130       -0.009197
#
#                           EnvironmentSatisfaction  ...  PerformanceRating  \
# Age                                      0.010146  ...           0.001904
# Attrition                               -0.103369  ...           0.002889
# BusinessTravel                           0.004174  ...          -0.026341
# DailyRate                                0.018355  ...           0.000473
# Department                              -0.019395  ...          -0.024604
# DistanceFromHome                        -0.016075  ...           0.027110
# Education                               -0.027128  ...          -0.024539
# EducationField                           0.043163  ...          -0.005614
# EmployeeNumber                           0.017621  ...          -0.020359
# EnvironmentSatisfaction                  1.000000  ...          -0.029548
# Gender                                   0.000508  ...          -0.013859
# HourlyRate                              -0.049857  ...          -0.002172
# JobInvolvement                          -0.008278  ...          -0.029071
# JobLevel                                 0.001212  ...          -0.021222
# JobRole                                 -0.017321  ...          -0.024233
# JobSatisfaction                         -0.006784  ...           0.002297
# MaritalStatus                           -0.003593  ...           0.005207
# MonthlyIncome                           -0.006259  ...          -0.017120
# MonthlyRate                              0.037600  ...          -0.009811
# NumCompaniesWorked                       0.012594  ...          -0.014095
# OverTime                                 0.070132  ...           0.004369
# PercentSalaryHike                       -0.031701  ...           0.773550
# PerformanceRating                       -0.029548  ...           1.000000
# RelationshipSatisfaction                 0.007665  ...          -0.031351
# StockOptionLevel                         0.003432  ...           0.003506
# TotalWorkingYears                       -0.002693  ...           0.006744
# TrainingTimesLastYear                   -0.019359  ...          -0.015579
# WorkLifeBalance                          0.027627  ...           0.002572
# YearsAtCompany                           0.001458  ...           0.003435
# YearsInCurrentRole                       0.018007  ...           0.034986
# YearsSinceLastPromotion                  0.016194  ...           0.017896
# YearsWithCurrManager                    -0.004999  ...           0.022827
#
#                           RelationshipSatisfaction  StockOptionLevel  \
# Age                                       0.053535          0.037510
# Attrition                                -0.045872         -0.137145
# BusinessTravel                           -0.035986         -0.016727
# DailyRate                                 0.007846          0.042143
# Department                               -0.022414         -0.012193
# DistanceFromHome                          0.006557          0.044872
# Education                                -0.009118          0.018422
# EducationField                           -0.004378         -0.016185
# EmployeeNumber                           -0.069861          0.062227
# EnvironmentSatisfaction                   0.007665          0.003432
# Gender                                    0.022868          0.012716
# HourlyRate                                0.001330          0.050263
# JobInvolvement                            0.034297          0.021523
# JobLevel                                  0.021642          0.013984
# JobRole                                  -0.020218         -0.019171
# JobSatisfaction                          -0.012454          0.010690
# MaritalStatus                             0.022549         -0.662577
# MonthlyIncome                             0.025873          0.005408
# MonthlyRate                              -0.004085         -0.034323
# NumCompaniesWorked                        0.052733          0.030075
# OverTime                                  0.048493         -0.000449
# PercentSalaryHike                        -0.040490          0.007528
# PerformanceRating                        -0.031351          0.003506
# RelationshipSatisfaction                  1.000000         -0.045952
# StockOptionLevel                         -0.045952          1.000000
# TotalWorkingYears                         0.024054          0.010136
# TrainingTimesLastYear                     0.002497          0.011274
# WorkLifeBalance                           0.019604          0.004129
# YearsAtCompany                            0.019367          0.015058
# YearsInCurrentRole                       -0.015123          0.050818
# YearsSinceLastPromotion                   0.033493          0.014352
# YearsWithCurrManager                     -0.000867          0.024698
#
#                           TotalWorkingYears  TrainingTimesLastYear  \
# Age                                0.680381              -0.019621
# Attrition                         -0.171063              -0.059478
# BusinessTravel                     0.034226               0.015240
# DailyRate                          0.014515               0.002453
# Department                        -0.015762               0.036875
# DistanceFromHome                   0.004628              -0.036942
# Education                          0.148280              -0.025100
# EducationField                    -0.027848               0.049195
# EmployeeNumber                    -0.014365               0.023603
# EnvironmentSatisfaction           -0.002693              -0.019359
# Gender                            -0.046881              -0.038787
# HourlyRate                        -0.002334              -0.008548
# JobInvolvement                    -0.005533              -0.015338
# JobLevel                           0.782208              -0.018191
# JobRole                           -0.145439               0.001342
# JobSatisfaction                   -0.020185              -0.005779
# MaritalStatus                     -0.077886               0.010629
# MonthlyIncome                      0.772893              -0.021736
# MonthlyRate                        0.026442               0.001467
# NumCompaniesWorked                 0.237639              -0.066054
# OverTime                           0.012754              -0.079113
# PercentSalaryHike                 -0.020608              -0.005221
# PerformanceRating                  0.006744              -0.015579
# RelationshipSatisfaction           0.024054               0.002497
# StockOptionLevel                   0.010136               0.011274
# TotalWorkingYears                  1.000000              -0.035662
# TrainingTimesLastYear             -0.035662               1.000000
# WorkLifeBalance                    0.001008               0.028072
# YearsAtCompany                     0.628133               0.003569
# YearsInCurrentRole                 0.460365              -0.005738
# YearsSinceLastPromotion            0.404858              -0.002067
# YearsWithCurrManager               0.459188              -0.004096
#
#                           WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# Age                             -0.021490        0.311309            0.212901
# Attrition                       -0.063939       -0.134392           -0.160545
# BusinessTravel                  -0.011256       -0.014575           -0.011497
# DailyRate                       -0.037848       -0.034055            0.009932
# Department                       0.026383        0.022920            0.056315
# DistanceFromHome                -0.026556        0.009508            0.018845
# Education                        0.009819        0.069114            0.060236
# EducationField                   0.041191       -0.018692           -0.010506
# EmployeeNumber                   0.010309       -0.011240           -0.008416
# EnvironmentSatisfaction          0.027627        0.001458            0.018007
# Gender                          -0.002753       -0.029747           -0.041483
# HourlyRate                      -0.004607       -0.019582           -0.024106
# JobInvolvement                  -0.014617       -0.021355            0.008717
# JobLevel                         0.037818        0.534739            0.389447
# JobRole                          0.027764       -0.083657           -0.028354
# JobSatisfaction                 -0.019459       -0.003803           -0.002305
# MaritalStatus                    0.014708       -0.059986           -0.065822
# MonthlyIncome                    0.030683        0.514285            0.363818
# MonthlyRate                      0.007963       -0.023655           -0.012815
# NumCompaniesWorked              -0.008366       -0.118421           -0.090754
# OverTime                        -0.027092       -0.011687           -0.029758
# PercentSalaryHike               -0.003280       -0.035991           -0.001520
# PerformanceRating                0.002572        0.003435            0.034986
# RelationshipSatisfaction         0.019604        0.019367           -0.015123
# StockOptionLevel                 0.004129        0.015058            0.050818
# TotalWorkingYears                0.001008        0.628133            0.460365
# TrainingTimesLastYear            0.028072        0.003569           -0.005738
# WorkLifeBalance                  1.000000        0.012089            0.049856
# YearsAtCompany                   0.012089        1.000000            0.758754
# YearsInCurrentRole               0.049856        0.758754            1.000000
# YearsSinceLastPromotion          0.008941        0.618409            0.548056
# YearsWithCurrManager             0.002759        0.769212            0.714365
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                      0.216513              0.202089
# Attrition                               -0.033019             -0.156199
# BusinessTravel                          -0.032591             -0.022636
# DailyRate                               -0.033229             -0.026363
# Department                               0.040061              0.034282
# DistanceFromHome                         0.010029              0.014406
# Education                                0.054254              0.069065
# EducationField                           0.002326             -0.004130
# EmployeeNumber                          -0.009019             -0.009197
# EnvironmentSatisfaction                  0.016194             -0.004999
# Gender                                  -0.026985             -0.030599
# HourlyRate                              -0.026716             -0.020123
# JobInvolvement                          -0.024184              0.025976
# JobLevel                                 0.353885              0.375281
# JobRole                                 -0.046384             -0.041150
# JobSatisfaction                         -0.018214             -0.027656
# MaritalStatus                           -0.030915             -0.038570
# MonthlyIncome                            0.344978              0.344079
# MonthlyRate                              0.001567             -0.036746
# NumCompaniesWorked                      -0.036814             -0.110319
# OverTime                                -0.012239             -0.041586
# PercentSalaryHike                       -0.022154             -0.011985
# PerformanceRating                        0.017896              0.022827
# RelationshipSatisfaction                 0.033493             -0.000867
# StockOptionLevel                         0.014352              0.024698
# TotalWorkingYears                        0.404858              0.459188
# TrainingTimesLastYear                   -0.002067             -0.004096
# WorkLifeBalance                          0.008941              0.002759
# YearsAtCompany                           0.618409              0.769212
# YearsInCurrentRole                       0.548056              0.714365
# YearsSinceLastPromotion                  1.000000              0.510224
# YearsWithCurrManager                     0.510224              1.000000
#
# [32 rows x 32 columns]

# %%
plt.figure(figsize=(15,10))
sns.heatmap(hra.corr(),cmap='afmhot_r')

# %% [markdown]
# Observations:
#
# 1. Attrition has a negative correlaton with age.
# 2. percent salary hike,performancerating are positively correlated.
# 3. YearsInCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager are positively correlated with each other.

# %%
# Checking skewness

hra.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome            0.958118
# Education                  -0.289681
# EducationField              0.550371
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# YearsWithCurrManager        0.833451
# dtype: float64

# %%
#Treating skewness using Powertransform
from sklearn.preprocessing import PowerTransformer
list=['Age', 'BusinessTravel', 'DailyRate', 'Department','DistanceFromHome', 'Education', 'EducationField','EmployeeNumber','EnvironmentSatisfaction', 'Gender', 'HourlyRate','JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction','MaritalStatus', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating','RelationshipSatisfaction', 'StockOptionLevel','TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance','YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion','YearsWithCurrManager']
pt=PowerTransformer(method='yeo-johnson')
for i in list:
    if hra.skew().loc[i]>0.55:
        hra[i]=pt.fit_transform(hra[i].values.reshape(-1,1))
    if hra.skew().loc[i]<-0.55:
        hra[i]=pt.fit_transform(hra[i].values.reshape(-1,1))
    else:
        hra[i]=hra[i]

# %%
hra.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -0.970506
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome           -0.007468
# Education                  -0.289681
# EducationField             -0.008386
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    0.103624
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          0.014814
# OverTime                    0.964489
# PercentSalaryHike           0.116250
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.087019
# TotalWorkingYears          -0.010653
# TrainingTimesLastYear       0.058058
# WorkLifeBalance            -0.012286
# YearsAtCompany             -0.008683
# YearsInCurrentRole         -0.060849
# YearsSinceLastPromotion     0.212129
# YearsWithCurrManager       -0.067565
# dtype: float64

# %%
#Removing outliers
# from scipy.stats import zscore
z=np.abs(zscore(hra))

# %%
hras=hra[(z<3).all(axis=1)]

# %%
hras
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1        0.635468       1102           2         -1.494085
# 1      49          0       -1.392865        279           1          0.243416
# 2      37          1        0.635468       1373           1         -1.031215
# 3      33          0       -1.392865       1392           1         -0.700347
# 4      27          0        0.635468        591           1         -1.031215
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0       -1.392865        884           1          1.407126
# 1466   39          0        0.635468        613           1         -0.050827
# 1467   27          0        0.635468        155           1         -0.442291
# 1468   49          0       -1.392865       1023           2         -1.031215
# 1469   34          0        0.635468        628           1          0.243416
#
#       Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  ...  \
# 0             2       -0.960488               1                        2  ...
# 1             1       -0.960488               2                        3  ...
# 2             2        1.247620               4                        4  ...
# 3             4       -0.960488               5                        4  ...
# 4             1        0.697390               7                        1  ...
# ...         ...             ...             ...                      ...  ...
# 1465          2        0.697390            2061                        3  ...
# 1466          1        0.697390            2062                        4  ...
# 1467          3       -0.960488            2064                        2  ...
# 1468          3        0.697390            2065                        4  ...
# 1469          3        0.697390            2068                        2  ...
#
#       PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0             -0.423557                         1         -1.087933
# 1              2.348814                         4          0.548969
# 2             -0.423557                         2         -1.087933
# 3             -0.423557                         3         -1.087933
# 4             -0.423557                         4          0.548969
# ...                 ...                       ...               ...
# 1465          -0.423557                         3          0.548969
# 1466          -0.423557                         1          0.548969
# 1467           2.348814                         2          0.548969
# 1468          -0.423557                         4         -1.087933
# 1469          -0.423557                         1         -1.087933
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0             -0.244305              -2.579073        -2.144446
# 1              0.052495               0.217384         0.276821
# 2             -0.410500               0.217384         0.276821
# 3             -0.244305               0.217384         0.276821
# 4             -0.592063               0.217384         0.276821
# ...                 ...                    ...              ...
# 1465           0.859893               0.217384         0.276821
# 1466          -0.090665               1.615639         0.276821
# 1467          -0.592063              -2.579073         0.276821
# 1468           0.859893               0.217384        -1.108624
# 1469          -0.592063               0.217384         1.998177
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0           0.139692            0.205562                -1.094862
# 1           0.762660            0.883888                 0.096854
# 2          -2.229592           -1.596434                -1.094862
# 3           0.482432            0.883888                 0.905592
# 4          -0.951540           -0.446645                 0.607464
# ...              ...                 ...                      ...
# 1465       -0.066114           -0.446645                -1.094862
# 1466        0.320677            0.883888                 0.096854
# 1467        0.139692           -0.446645                -1.094862
# 1468        0.628829            0.682995                -1.094862
# 1469       -0.305280           -0.089615                 0.096854
#
#       YearsWithCurrManager
# 0                 0.490147
# 1                 0.909635
# 2                -1.550156
# 3                -1.550156
# 4                -0.406881
# ...                    ...
# 1465             -0.053000
# 1466              0.909635
# 1467             -0.053000
# 1468              1.090110
# 1469             -0.406881
#
# [1470 rows x 32 columns]

# %%
print('Shape before removing outliers:',hra.shape)
print('Shape after removing outliers: ',hras.shape)
# Out:
# Shape before removing outliers: (1470, 32)
# Shape after removing outliers:  (1470, 32)

# %%
hras.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -0.970506
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome           -0.007468
# Education                  -0.289681
# EducationField             -0.008386
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    0.103624
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          0.014814
# OverTime                    0.964489
# PercentSalaryHike           0.116250
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.087019
# TotalWorkingYears          -0.010653
# TrainingTimesLastYear       0.058058
# WorkLifeBalance            -0.012286
# YearsAtCompany             -0.008683
# YearsInCurrentRole         -0.060849
# YearsSinceLastPromotion     0.212129
# YearsWithCurrManager       -0.067565
# dtype: float64

# %%
x=hras.drop(['Attrition'],axis=1)
x
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41        0.635468       1102           2         -1.494085          2
# 1      49       -1.392865        279           1          0.243416          1
# 2      37        0.635468       1373           1         -1.031215          2
# 3      33       -1.392865       1392           1         -0.700347          4
# 4      27        0.635468        591           1         -1.031215          1
# ...   ...             ...        ...         ...               ...        ...
# 1465   36       -1.392865        884           1          1.407126          2
# 1466   39        0.635468        613           1         -0.050827          1
# 1467   27        0.635468        155           1         -0.442291          3
# 1468   49       -1.392865       1023           2         -1.031215          3
# 1469   34        0.635468        628           1          0.243416          3
#
#       EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  ...  \
# 0          -0.960488               1                        2       0  ...
# 1          -0.960488               2                        3       1  ...
# 2           1.247620               4                        4       1  ...
# 3          -0.960488               5                        4       0  ...
# 4           0.697390               7                        1       1  ...
# ...              ...             ...                      ...     ...  ...
# 1465        0.697390            2061                        3       1  ...
# 1466        0.697390            2062                        4       1  ...
# 1467       -0.960488            2064                        2       1  ...
# 1468        0.697390            2065                        4       1  ...
# 1469        0.697390            2068                        2       1  ...
#
#       PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0             -0.423557                         1         -1.087933
# 1              2.348814                         4          0.548969
# 2             -0.423557                         2         -1.087933
# 3             -0.423557                         3         -1.087933
# 4             -0.423557                         4          0.548969
# ...                 ...                       ...               ...
# 1465          -0.423557                         3          0.548969
# 1466          -0.423557                         1          0.548969
# 1467           2.348814                         2          0.548969
# 1468          -0.423557                         4         -1.087933
# 1469          -0.423557                         1         -1.087933
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0             -0.244305              -2.579073        -2.144446
# 1              0.052495               0.217384         0.276821
# 2             -0.410500               0.217384         0.276821
# 3             -0.244305               0.217384         0.276821
# 4             -0.592063               0.217384         0.276821
# ...                 ...                    ...              ...
# 1465           0.859893               0.217384         0.276821
# 1466          -0.090665               1.615639         0.276821
# 1467          -0.592063              -2.579073         0.276821
# 1468           0.859893               0.217384        -1.108624
# 1469          -0.592063               0.217384         1.998177
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0           0.139692            0.205562                -1.094862
# 1           0.762660            0.883888                 0.096854
# 2          -2.229592           -1.596434                -1.094862
# 3           0.482432            0.883888                 0.905592
# 4          -0.951540           -0.446645                 0.607464
# ...              ...                 ...                      ...
# 1465       -0.066114           -0.446645                -1.094862
# 1466        0.320677            0.883888                 0.096854
# 1467        0.139692           -0.446645                -1.094862
# 1468        0.628829            0.682995                -1.094862
# 1469       -0.305280           -0.089615                 0.096854
#
#       YearsWithCurrManager
# 0                 0.490147
# 1                 0.909635
# 2                -1.550156
# 3                -1.550156
# 4                -0.406881
# ...                    ...
# 1465             -0.053000
# 1466              0.909635
# 1467             -0.053000
# 1468              1.090110
# 1469             -0.406881
#
# [1470 rows x 31 columns]

# %%
y=hras['Attrition']
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int32

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
xx=sc.fit_transform(x)
x=pd.DataFrame(xx,columns=x.columns)

# %%
x
# Out:
#            Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0     0.446350        0.635468   0.742527    1.401512         -1.494085
# 1     1.322365       -1.392865  -1.297775   -0.493817          0.243416
# 2     0.008343        0.635468   1.414363   -0.493817         -1.031215
# 3    -0.429664       -1.392865   1.461466   -0.493817         -0.700347
# 4    -1.086676        0.635468  -0.524295   -0.493817         -1.031215
# ...        ...             ...        ...         ...               ...
# 1465 -0.101159       -1.392865   0.202082   -0.493817          1.407126
# 1466  0.227347        0.635468  -0.469754   -0.493817         -0.050827
# 1467 -1.086676        0.635468  -1.605183   -0.493817         -0.442291
# 1468  1.322365       -1.392865   0.546677    1.401512         -1.031215
# 1469 -0.320163        0.635468  -0.432568   -0.493817          0.243416
#
#       Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# 0     -0.891688       -0.960488       -1.701283                -0.660531
# 1     -1.868426       -0.960488       -1.699621                 0.254625
# 2     -0.891688        1.247620       -1.696298                 1.169781
# 3      1.061787       -0.960488       -1.694636                 1.169781
# 4     -1.868426        0.697390       -1.691313                -1.575686
# ...         ...             ...             ...                      ...
# 1465  -0.891688        0.697390        1.721670                 0.254625
# 1466  -1.868426        0.697390        1.723332                 1.169781
# 1467   0.085049       -0.960488        1.726655                -0.660531
# 1468   0.085049        0.697390        1.728317                 1.169781
# 1469   0.085049        0.697390        1.733302                -0.660531
#
#         Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 0    -1.224745  ...          -0.426230                 -1.584178
# 1     0.816497  ...           2.346151                  1.191438
# 2     0.816497  ...          -0.426230                 -0.658973
# 3    -1.224745  ...          -0.426230                  0.266233
# 4     0.816497  ...          -0.426230                  1.191438
# ...        ...  ...                ...                       ...
# 1465  0.816497  ...          -0.426230                  0.266233
# 1466  0.816497  ...          -0.426230                 -1.584178
# 1467  0.816497  ...           2.346151                 -0.658973
# 1468  0.816497  ...          -0.426230                  1.191438
# 1469  0.816497  ...          -0.426230                 -1.584178
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0            -1.087933          -0.244305              -2.579073
# 1             0.548969           0.052495               0.217384
# 2            -1.087933          -0.410500               0.217384
# 3            -1.087933          -0.244305               0.217384
# 4             0.548969          -0.592063               0.217384
# ...                ...                ...                    ...
# 1465          0.548969           0.859893               0.217384
# 1466          0.548969          -0.090665               1.615639
# 1467          0.548969          -0.592063              -2.579073
# 1468         -1.087933           0.859893               0.217384
# 1469         -1.087933          -0.592063               0.217384
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0           -2.144446        0.139692            0.205562
# 1            0.276821        0.762660            0.883888
# 2            0.276821       -2.229592           -1.596434
# 3            0.276821        0.482432            0.883888
# 4            0.276821       -0.951540           -0.446645
# ...               ...             ...                 ...
# 1465         0.276821       -0.066114           -0.446645
# 1466         0.276821        0.320677            0.883888
# 1467         0.276821        0.139692           -0.446645
# 1468        -1.108624        0.628829            0.682995
# 1469         1.998177       -0.305280           -0.089615
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                   -1.094862              0.490147
# 1                    0.096854              0.909635
# 2                   -1.094862             -1.550156
# 3                    0.905592             -1.550156
# 4                    0.607464             -0.406881
# ...                       ...                   ...
# 1465                -1.094862             -0.053000
# 1466                 0.096854              0.909635
# 1467                -1.094862             -0.053000
# 1468                -1.094862              1.090110
# 1469                 0.096854             -0.406881
#
# [1470 rows x 31 columns]

# %%
#from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LogisticRegression
#from sklearn.svm import SVC
#from sklearn.naive_bayes import GaussianNB
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.ensemble import RandomForestClassifier
#from sklearn.metrics import accuracy_score, confusion_matrix,classification_report

# %%
list=[LogisticRegression(),GaussianNB(),SVC(),DecisionTreeClassifier(),KNeighborsClassifier()]
for g in list:
    r_max=0
    print('for the algorithm: ',g)
    for i in range(33,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=i)
        g.fit(x_train,y_train)
        pred=g.predict(x_test)
        accuracy=accuracy_score(pred,y_test)
        print('accuracy score corresponding to random state',i,'is: ',accuracy)
        if accuracy>r_max:
            r_max=accuracy
            final=i
    print('\n')
    print('Max accuracy score corresponding to: ', final,'is: ',r_max)
    print('✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦')
    print('\n')
# Out:
# for the algorithm:  LogisticRegression()
# accuracy score corresponding to random state 33 is:  0.8505434782608695
# accuracy score corresponding to random state 34 is:  0.8722826086956522
# accuracy score corresponding to random state 35 is:  0.8777173913043478
# accuracy score corresponding to random state 36 is:  0.8614130434782609
# accuracy score corresponding to random state 37 is:  0.8804347826086957
# accuracy score corresponding to random state 38 is:  0.8777173913043478
# accuracy score corresponding to random state 39 is:  0.8777173913043478
# accuracy score corresponding to random state 40 is:  0.8967391304347826
# accuracy score corresponding to random state 41 is:  0.875
# accuracy score corresponding to random state 42 is:  0.8885869565217391
# accuracy score corresponding to random state 43 is:  0.8369565217391305
# accuracy score corresponding to random state 44 is:  0.8831521739130435
# accuracy score corresponding to random state 45 is:  0.8586956521739131
# accuracy score corresponding to random state 46 is:  0.8668478260869565
# accuracy score corresponding to random state 47 is:  0.875
# accuracy score corresponding to random state 48 is:  0.8695652173913043
# accuracy score corresponding to random state 49 is:  0.8614130434782609
# accuracy score corresponding to random state 50 is:  0.8614130434782609
# accuracy score corresponding to random state 51 is:  0.875
# accuracy score corresponding to random state 52 is:  0.8668478260869565
# accuracy score corresponding to random state 53 is:  0.8695652173913043
# accuracy score corresponding to random state 54 is:  0.8559782608695652
# accuracy score corresponding to random state 55 is:  0.8831521739130435
# accuracy score corresponding to random state 56 is:  0.8668478260869565
# accuracy score corresponding to random state 57 is:  0.8858695652173914
# accuracy score corresponding to random state 58 is:  0.8396739130434783
# accuracy score corresponding to random state 59 is:  0.8831521739130435
# accuracy score corresponding to random state 60 is:  0.8641304347826086
# accuracy score corresponding to random state 61 is:  0.8695652173913043
# accuracy score corresponding to random state 62 is:  0.8668478260869565
# accuracy score corresponding to random state 63 is:  0.8831521739130435
# accuracy score corresponding to random state 64 is:  0.8804347826086957
# accuracy score corresponding to random state 65 is:  0.8722826086956522
# accuracy score corresponding to random state 66 is:  0.875
# accuracy score corresponding to random state 67 is:  0.8777173913043478
# accuracy score corresponding to random state 68 is:  0.8260869565217391
# accuracy score corresponding to random state 69 is:  0.8315217391304348
# accuracy score corresponding to random state 70 is:  0.8478260869565217
# accuracy score corresponding to random state 71 is:  0.8722826086956522
# accuracy score corresponding to random state 72 is:  0.8722826086956522
# accuracy score corresponding to random state 73 is:  0.875
# accuracy score corresponding to random state 74 is:  0.8586956521739131
# accuracy score corresponding to random state 75 is:  0.8288043478260869
# accuracy score corresponding to random state 76 is:  0.8532608695652174
# accuracy score corresponding to random state 77 is:  0.8614130434782609
# accuracy score corresponding to random state 78 is:  0.8831521739130435
# accuracy score corresponding to random state 79 is:  0.8342391304347826
# accuracy score corresponding to random state 80 is:  0.8722826086956522
# accuracy score corresponding to random state 81 is:  0.8885869565217391
# accuracy score corresponding to random state 82 is:  0.8804347826086957
# accuracy score corresponding to random state 83 is:  0.8804347826086957
# accuracy score corresponding to random state 84 is:  0.8831521739130435
# accuracy score corresponding to random state 85 is:  0.8831521739130435
# accuracy score corresponding to random state 86 is:  0.8695652173913043
# accuracy score corresponding to random state 87 is:  0.8722826086956522
# accuracy score corresponding to random state 88 is:  0.8586956521739131
# accuracy score corresponding to random state 89 is:  0.8641304347826086
# accuracy score corresponding to random state 90 is:  0.8722826086956522
# accuracy score corresponding to random state 91 is:  0.8858695652173914
# accuracy score corresponding to random state 92 is:  0.875
# accuracy score corresponding to random state 93 is:  0.8913043478260869
# accuracy score corresponding to random state 94 is:  0.875
# accuracy score corresponding to random state 95 is:  0.8858695652173914
# accuracy score corresponding to random state 96 is:  0.8777173913043478
# accuracy score corresponding to random state 97 is:  0.8614130434782609
# accuracy score corresponding to random state 98 is:  0.8885869565217391
# accuracy score corresponding to random state 99 is:  0.8804347826086957
# accuracy score corresponding to random state 100 is:  0.8641304347826086
#
#
# Max accuracy score corresponding to:  40 is:  0.8967391304347826
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
#
#
# for the algorithm:  GaussianNB()
# accuracy score corresponding to random state 33 is:  0.8206521739130435
# accuracy score corresponding to random state 34 is:  0.8043478260869565
# accuracy score corresponding to random state 35 is:  0.8070652173913043
# accuracy score corresponding to random state 36 is:  0.8179347826086957
# accuracy score corresponding to random state 37 is:  0.8260869565217391
# accuracy score corresponding to random state 38 is:  0.8016304347826086
# accuracy score corresponding to random state 39 is:  0.8016304347826086
# accuracy score corresponding to random state 40 is:  0.8532608695652174
# accuracy score corresponding to random state 41 is:  0.842391304347826
# accuracy score corresponding to random state 42 is:  0.8043478260869565
# accuracy score corresponding to random state 43 is:  0.8070652173913043
# accuracy score corresponding to random state 44 is:  0.8152173913043478
# accuracy score corresponding to random state 45 is:  0.8043478260869565
# accuracy score corresponding to random state 46 is:  0.7635869565217391
# accuracy score corresponding to random state 47 is:  0.7554347826086957
# accuracy score corresponding to random state 48 is:  0.8396739130434783
# accuracy score corresponding to random state 49 is:  0.8125
# accuracy score corresponding to random state 50 is:  0.8152173913043478
# accuracy score corresponding to random state 51 is:  0.8288043478260869
# accuracy score corresponding to random state 52 is:  0.8260869565217391
# accuracy score corresponding to random state 53 is:  0.8260869565217391
# accuracy score corresponding to random state 54 is:  0.8260869565217391
# accuracy score corresponding to random state 55 is:  0.8152173913043478
# accuracy score corresponding to random state 56 is:  0.8016304347826086
# accuracy score corresponding to random state 57 is:  0.8016304347826086
# accuracy score corresponding to random state 58 is:  0.7635869565217391
# accuracy score corresponding to random state 59 is:  0.845108695652174
# accuracy score corresponding to random state 60 is:  0.7744565217391305
# accuracy score corresponding to random state 61 is:  0.782608695652174
# accuracy score corresponding to random state 62 is:  0.7989130434782609
# accuracy score corresponding to random state 63 is:  0.8179347826086957
# accuracy score corresponding to random state 64 is:  0.8043478260869565
# accuracy score corresponding to random state 65 is:  0.7554347826086957
# accuracy score corresponding to random state 66 is:  0.8152173913043478
# accuracy score corresponding to random state 67 is:  0.8342391304347826
# accuracy score corresponding to random state 68 is:  0.7961956521739131
# accuracy score corresponding to random state 69 is:  0.7934782608695652
# accuracy score corresponding to random state 70 is:  0.8206521739130435
# accuracy score corresponding to random state 71 is:  0.7472826086956522
# accuracy score corresponding to random state 72 is:  0.8097826086956522
# accuracy score corresponding to random state 73 is:  0.7907608695652174
# accuracy score corresponding to random state 74 is:  0.7717391304347826
# accuracy score corresponding to random state 75 is:  0.7961956521739131
# accuracy score corresponding to random state 76 is:  0.782608695652174
# accuracy score corresponding to random state 77 is:  0.7690217391304348
# accuracy score corresponding to random state 78 is:  0.8016304347826086
# accuracy score corresponding to random state 79 is:  0.7663043478260869
# accuracy score corresponding to random state 80 is:  0.8043478260869565
# accuracy score corresponding to random state 81 is:  0.8478260869565217
# accuracy score corresponding to random state 82 is:  0.8260869565217391
# accuracy score corresponding to random state 83 is:  0.8260869565217391
# accuracy score corresponding to random state 84 is:  0.8369565217391305
# accuracy score corresponding to random state 85 is:  0.8070652173913043
# accuracy score corresponding to random state 86 is:  0.8043478260869565
# accuracy score corresponding to random state 87 is:  0.8288043478260869
# accuracy score corresponding to random state 88 is:  0.782608695652174
# accuracy score corresponding to random state 89 is:  0.8260869565217391
# accuracy score corresponding to random state 90 is:  0.7989130434782609
# accuracy score corresponding to random state 91 is:  0.8586956521739131
# accuracy score corresponding to random state 92 is:  0.8152173913043478
# accuracy score corresponding to random state 93 is:  0.8288043478260869
# accuracy score corresponding to random state 94 is:  0.8125
# accuracy score corresponding to random state 95 is:  0.8125
# accuracy score corresponding to random state 96 is:  0.8016304347826086
# accuracy score corresponding to random state 97 is:  0.7934782608695652
# accuracy score corresponding to random state 98 is:  0.8152173913043478
# accuracy score corresponding to random state 99 is:  0.7853260869565217
# accuracy score corresponding to random state 100 is:  0.7771739130434783
#
#
# Max accuracy score corresponding to:  91 is:  0.8586956521739131
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
#
#
# for the algorithm:  SVC()
# accuracy score corresponding to random state 33 is:  0.8478260869565217
# accuracy score corresponding to random state 34 is:  0.8695652173913043
# accuracy score corresponding to random state 35 is:  0.8858695652173914
# accuracy score corresponding to random state 36 is:  0.8668478260869565
# accuracy score corresponding to random state 37 is:  0.8668478260869565
# accuracy score corresponding to random state 38 is:  0.8559782608695652
# accuracy score corresponding to random state 39 is:  0.8668478260869565
# accuracy score corresponding to random state 40 is:  0.8804347826086957
# accuracy score corresponding to random state 41 is:  0.8804347826086957
# accuracy score corresponding to random state 42 is:  0.875
# accuracy score corresponding to random state 43 is:  0.8260869565217391
# accuracy score corresponding to random state 44 is:  0.8641304347826086
# accuracy score corresponding to random state 45 is:  0.8396739130434783
# accuracy score corresponding to random state 46 is:  0.8369565217391305
# accuracy score corresponding to random state 47 is:  0.8641304347826086
# accuracy score corresponding to random state 48 is:  0.8777173913043478
# accuracy score corresponding to random state 49 is:  0.8559782608695652
# accuracy score corresponding to random state 50 is:  0.8478260869565217
# accuracy score corresponding to random state 51 is:  0.8641304347826086
# accuracy score corresponding to random state 52 is:  0.8722826086956522
# accuracy score corresponding to random state 53 is:  0.8668478260869565
# accuracy score corresponding to random state 54 is:  0.845108695652174
# accuracy score corresponding to random state 55 is:  0.8885869565217391
# accuracy score corresponding to random state 56 is:  0.8559782608695652
# accuracy score corresponding to random state 57 is:  0.8777173913043478
# accuracy score corresponding to random state 58 is:  0.8369565217391305
# accuracy score corresponding to random state 59 is:  0.8722826086956522
# accuracy score corresponding to random state 60 is:  0.8586956521739131
# accuracy score corresponding to random state 61 is:  0.8586956521739131
# accuracy score corresponding to random state 62 is:  0.8586956521739131
# accuracy score corresponding to random state 63 is:  0.8641304347826086
# accuracy score corresponding to random state 64 is:  0.8722826086956522
# accuracy score corresponding to random state 65 is:  0.8586956521739131
# accuracy score corresponding to random state 66 is:  0.8668478260869565
# accuracy score corresponding to random state 67 is:  0.8777173913043478
# accuracy score corresponding to random state 68 is:  0.8070652173913043
# accuracy score corresponding to random state 69 is:  0.8206521739130435
# accuracy score corresponding to random state 70 is:  0.8288043478260869
# accuracy score corresponding to random state 71 is:  0.8804347826086957
# accuracy score corresponding to random state 72 is:  0.8695652173913043
# accuracy score corresponding to random state 73 is:  0.8940217391304348
# accuracy score corresponding to random state 74 is:  0.8369565217391305
# accuracy score corresponding to random state 75 is:  0.8369565217391305
# accuracy score corresponding to random state 76 is:  0.8505434782608695
# accuracy score corresponding to random state 77 is:  0.8586956521739131
# accuracy score corresponding to random state 78 is:  0.8804347826086957
# accuracy score corresponding to random state 79 is:  0.8179347826086957
# accuracy score corresponding to random state 80 is:  0.8532608695652174
# accuracy score corresponding to random state 81 is:  0.8668478260869565
# accuracy score corresponding to random state 82 is:  0.8614130434782609
# accuracy score corresponding to random state 83 is:  0.8858695652173914
# accuracy score corresponding to random state 84 is:  0.8695652173913043
# accuracy score corresponding to random state 85 is:  0.8831521739130435
# accuracy score corresponding to random state 86 is:  0.8695652173913043
# accuracy score corresponding to random state 87 is:  0.8559782608695652
# accuracy score corresponding to random state 88 is:  0.8342391304347826
# accuracy score corresponding to random state 89 is:  0.8505434782608695
# accuracy score corresponding to random state 90 is:  0.8722826086956522
# accuracy score corresponding to random state 91 is:  0.8559782608695652
# accuracy score corresponding to random state 92 is:  0.8641304347826086
# accuracy score corresponding to random state 93 is:  0.8695652173913043
# accuracy score corresponding to random state 94 is:  0.8804347826086957
# accuracy score corresponding to random state 95 is:  0.8532608695652174
# accuracy score corresponding to random state 96 is:  0.8396739130434783
# accuracy score corresponding to random state 97 is:  0.8369565217391305
# accuracy score corresponding to random state 98 is:  0.8614130434782609
# accuracy score corresponding to random state 99 is:  0.8668478260869565
# accuracy score corresponding to random state 100 is:  0.8722826086956522
#
#
# Max accuracy score corresponding to:  73 is:  0.8940217391304348
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
#
#
# for the algorithm:  DecisionTreeClassifier()
# accuracy score corresponding to random state 33 is:  0.7744565217391305
# accuracy score corresponding to random state 34 is:  0.8016304347826086
# accuracy score corresponding to random state 35 is:  0.7771739130434783
# accuracy score corresponding to random state 36 is:  0.8233695652173914
# accuracy score corresponding to random state 37 is:  0.8206521739130435
# accuracy score corresponding to random state 38 is:  0.8016304347826086
# accuracy score corresponding to random state 39 is:  0.7608695652173914
# accuracy score corresponding to random state 40 is:  0.7880434782608695
# accuracy score corresponding to random state 41 is:  0.8179347826086957
# accuracy score corresponding to random state 42 is:  0.779891304347826
# accuracy score corresponding to random state 43 is:  0.7690217391304348
# accuracy score corresponding to random state 44 is:  0.782608695652174
# accuracy score corresponding to random state 45 is:  0.782608695652174
# accuracy score corresponding to random state 46 is:  0.7690217391304348
# accuracy score corresponding to random state 47 is:  0.7771739130434783
# accuracy score corresponding to random state 48 is:  0.8043478260869565
# accuracy score corresponding to random state 49 is:  0.779891304347826
# accuracy score corresponding to random state 50 is:  0.7635869565217391
# accuracy score corresponding to random state 51 is:  0.7608695652173914
# accuracy score corresponding to random state 52 is:  0.7853260869565217
# accuracy score corresponding to random state 53 is:  0.782608695652174
# accuracy score corresponding to random state 54 is:  0.7472826086956522
# accuracy score corresponding to random state 55 is:  0.7771739130434783
# accuracy score corresponding to random state 56 is:  0.7635869565217391
# accuracy score corresponding to random state 57 is:  0.7907608695652174
# accuracy score corresponding to random state 58 is:  0.7336956521739131
# accuracy score corresponding to random state 59 is:  0.7961956521739131
# accuracy score corresponding to random state 60 is:  0.7635869565217391
# accuracy score corresponding to random state 61 is:  0.7554347826086957
# accuracy score corresponding to random state 62 is:  0.779891304347826
# accuracy score corresponding to random state 63 is:  0.7608695652173914
# accuracy score corresponding to random state 64 is:  0.8097826086956522
# accuracy score corresponding to random state 65 is:  0.7717391304347826
# accuracy score corresponding to random state 66 is:  0.7934782608695652
# accuracy score corresponding to random state 67 is:  0.8097826086956522
# accuracy score corresponding to random state 68 is:  0.7554347826086957
# accuracy score corresponding to random state 69 is:  0.7391304347826086
# accuracy score corresponding to random state 70 is:  0.8097826086956522
# accuracy score corresponding to random state 71 is:  0.7907608695652174
# accuracy score corresponding to random state 72 is:  0.7961956521739131
# accuracy score corresponding to random state 73 is:  0.7880434782608695
# accuracy score corresponding to random state 74 is:  0.7635869565217391
# accuracy score corresponding to random state 75 is:  0.75
# accuracy score corresponding to random state 76 is:  0.7880434782608695
# accuracy score corresponding to random state 77 is:  0.7472826086956522
# accuracy score corresponding to random state 78 is:  0.8097826086956522
# accuracy score corresponding to random state 79 is:  0.7989130434782609
# accuracy score corresponding to random state 80 is:  0.7880434782608695
# accuracy score corresponding to random state 81 is:  0.8016304347826086
# accuracy score corresponding to random state 82 is:  0.7880434782608695
# accuracy score corresponding to random state 83 is:  0.7880434782608695
# accuracy score corresponding to random state 84 is:  0.7989130434782609
# accuracy score corresponding to random state 85 is:  0.7907608695652174
# accuracy score corresponding to random state 86 is:  0.8016304347826086
# accuracy score corresponding to random state 87 is:  0.7717391304347826
# accuracy score corresponding to random state 88 is:  0.7690217391304348
# accuracy score corresponding to random state 89 is:  0.7663043478260869
# accuracy score corresponding to random state 90 is:  0.7907608695652174
# accuracy score corresponding to random state 91 is:  0.7690217391304348
# accuracy score corresponding to random state 92 is:  0.8152173913043478
# accuracy score corresponding to random state 93 is:  0.7690217391304348
# accuracy score corresponding to random state 94 is:  0.7771739130434783
# accuracy score corresponding to random state 95 is:  0.7635869565217391
# accuracy score corresponding to random state 96 is:  0.7717391304347826
# accuracy score corresponding to random state 97 is:  0.7744565217391305
# accuracy score corresponding to random state 98 is:  0.7880434782608695
# accuracy score corresponding to random state 99 is:  0.75
# accuracy score corresponding to random state 100 is:  0.7961956521739131
#
#
# Max accuracy score corresponding to:  36 is:  0.8233695652173914
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
#
#
# for the algorithm:  KNeighborsClassifier()
# accuracy score corresponding to random state 33 is:  0.8369565217391305
# accuracy score corresponding to random state 34 is:  0.8586956521739131
# accuracy score corresponding to random state 35 is:  0.875
# accuracy score corresponding to random state 36 is:  0.8559782608695652
# accuracy score corresponding to random state 37 is:  0.8559782608695652
# accuracy score corresponding to random state 38 is:  0.8396739130434783
# accuracy score corresponding to random state 39 is:  0.8505434782608695
# accuracy score corresponding to random state 40 is:  0.8559782608695652
# accuracy score corresponding to random state 41 is:  0.875
# accuracy score corresponding to random state 42 is:  0.8695652173913043
# accuracy score corresponding to random state 43 is:  0.8152173913043478
# accuracy score corresponding to random state 44 is:  0.8532608695652174
# accuracy score corresponding to random state 45 is:  0.8315217391304348
# accuracy score corresponding to random state 46 is:  0.8097826086956522
# accuracy score corresponding to random state 47 is:  0.8369565217391305
# accuracy score corresponding to random state 48 is:  0.8641304347826086
# accuracy score corresponding to random state 49 is:  0.8532608695652174
# accuracy score corresponding to random state 50 is:  0.842391304347826
# accuracy score corresponding to random state 51 is:  0.845108695652174
# accuracy score corresponding to random state 52 is:  0.8505434782608695
# accuracy score corresponding to random state 53 is:  0.8532608695652174
# accuracy score corresponding to random state 54 is:  0.8396739130434783
# accuracy score corresponding to random state 55 is:  0.875
# accuracy score corresponding to random state 56 is:  0.8369565217391305
# accuracy score corresponding to random state 57 is:  0.8641304347826086
# accuracy score corresponding to random state 58 is:  0.8206521739130435
# accuracy score corresponding to random state 59 is:  0.8505434782608695
# accuracy score corresponding to random state 60 is:  0.8369565217391305
# accuracy score corresponding to random state 61 is:  0.845108695652174
# accuracy score corresponding to random state 62 is:  0.8369565217391305
# accuracy score corresponding to random state 63 is:  0.8559782608695652
# accuracy score corresponding to random state 64 is:  0.8614130434782609
# accuracy score corresponding to random state 65 is:  0.8641304347826086
# accuracy score corresponding to random state 66 is:  0.8478260869565217
# accuracy score corresponding to random state 67 is:  0.8614130434782609
# accuracy score corresponding to random state 68 is:  0.7907608695652174
# accuracy score corresponding to random state 69 is:  0.8043478260869565
# accuracy score corresponding to random state 70 is:  0.8179347826086957
# accuracy score corresponding to random state 71 is:  0.8505434782608695
# accuracy score corresponding to random state 72 is:  0.842391304347826
# accuracy score corresponding to random state 73 is:  0.8695652173913043
# accuracy score corresponding to random state 74 is:  0.8233695652173914
# accuracy score corresponding to random state 75 is:  0.8288043478260869
# accuracy score corresponding to random state 76 is:  0.8396739130434783
# accuracy score corresponding to random state 77 is:  0.8505434782608695
# accuracy score corresponding to random state 78 is:  0.8641304347826086
# accuracy score corresponding to random state 79 is:  0.8125
# accuracy score corresponding to random state 80 is:  0.8396739130434783
# accuracy score corresponding to random state 81 is:  0.8614130434782609
# accuracy score corresponding to random state 82 is:  0.8505434782608695
# accuracy score corresponding to random state 83 is:  0.8641304347826086
# accuracy score corresponding to random state 84 is:  0.8478260869565217
# accuracy score corresponding to random state 85 is:  0.8586956521739131
# accuracy score corresponding to random state 86 is:  0.8668478260869565
# accuracy score corresponding to random state 87 is:  0.842391304347826
# accuracy score corresponding to random state 88 is:  0.8125
# accuracy score corresponding to random state 89 is:  0.8396739130434783
# accuracy score corresponding to random state 90 is:  0.842391304347826
# accuracy score corresponding to random state 91 is:  0.8478260869565217
# accuracy score corresponding to random state 92 is:  0.842391304347826
# accuracy score corresponding to random state 93 is:  0.8641304347826086
# accuracy score corresponding to random state 94 is:  0.8532608695652174
# accuracy score corresponding to random state 95 is:  0.8342391304347826
# accuracy score corresponding to random state 96 is:  0.8260869565217391
# accuracy score corresponding to random state 97 is:  0.8260869565217391
# accuracy score corresponding to random state 98 is:  0.845108695652174
# accuracy score corresponding to random state 99 is:  0.8505434782608695
# accuracy score corresponding to random state 100 is:  0.8559782608695652
#
#
# Max accuracy score corresponding to:  35 is:  0.875
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦

# %%
list=[LogisticRegression(),GaussianNB(),SVC(),DecisionTreeClassifier(),KNeighborsClassifier()]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=40)
for j in list:
    print('for the algorithm: ',j)
    j.fit(x_train,y_train)
    scr=j.score(x_train,y_train)
    pred=j.predict(x_test)
    accuracy=accuracy_score(pred,y_test)
    print('The score is: ',scr)
    print('Accuracy score is: ',accuracy)
    print('confusion matrix: \n',confusion_matrix(pred,y_test))
    print('classification report: \n',classification_report(pred,y_test))
    print('✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦')
# Out:
# for the algorithm:  LogisticRegression()
# The score is:  0.8720508166969148
# Accuracy score is:  0.8967391304347826
# confusion matrix:
#  [[303  30]
#  [  8  27]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94       333
#            1       0.47      0.77      0.59        35
#
#     accuracy                           0.90       368
#    macro avg       0.72      0.84      0.76       368
# weighted avg       0.93      0.90      0.91       368
#
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
# for the algorithm:  GaussianNB()
# The score is:  0.8121597096188747
# Accuracy score is:  0.8532608695652174
# confusion matrix:
#  [[278  21]
#  [ 33  36]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91       299
#            1       0.63      0.52      0.57        69
#
#     accuracy                           0.85       368
#    macro avg       0.76      0.73      0.74       368
# weighted avg       0.84      0.85      0.85       368
#
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
# for the algorithm:  SVC()
# The score is:  0.9092558983666061
# Accuracy score is:  0.8804347826086957
# confusion matrix:
#  [[310  43]
#  [  1  14]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.88      0.93       353
#            1       0.25      0.93      0.39        15
#
#     accuracy                           0.88       368
#    macro avg       0.62      0.91      0.66       368
# weighted avg       0.97      0.88      0.91       368
#
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
# for the algorithm:  DecisionTreeClassifier()
# The score is:  1.0
# Accuracy score is:  0.7853260869565217
# confusion matrix:
#  [[271  39]
#  [ 40  18]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87       310
#            1       0.32      0.31      0.31        58
#
#     accuracy                           0.79       368
#    macro avg       0.59      0.59      0.59       368
# weighted avg       0.78      0.79      0.78       368
#
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
# for the algorithm:  KNeighborsClassifier()
# The score is:  0.868421052631579
# Accuracy score is:  0.8559782608695652
# confusion matrix:
#  [[309  51]
#  [  2   6]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.86      0.92       360
#            1       0.11      0.75      0.18         8
#
#     accuracy                           0.86       368
#    macro avg       0.55      0.80      0.55       368
# weighted avg       0.97      0.86      0.91       368
#
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦

# %%
#from sklearn.model_selection import cross_val_score

list=[LogisticRegression(),GaussianNB(),SVC(),DecisionTreeClassifier(),KNeighborsClassifier()]
for i in list:
    print(i,'\n')
    score=cross_val_score(i,x,y,cv=5,scoring='accuracy')
    print('Score: ',score)
    print('Mean score :',score.mean())
    print('Standard Deviation :',score.std())
    print('✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦\n')
# Out:
# LogisticRegression()
#
# Score:  [0.87755102 0.86054422 0.8707483  0.8707483  0.88435374]
# Mean score : 0.8727891156462585
# Standard Deviation : 0.007933267884143275
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
#
# GaussianNB()
#
# Score:  [0.85034014 0.80272109 0.79591837 0.79251701 0.85714286]
# Mean score : 0.8197278911564625
# Standard Deviation : 0.028048337589235764
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
#
# SVC()
#
# Score:  [0.86734694 0.84353741 0.8707483  0.85714286 0.87414966]
# Mean score : 0.8625850340136054
# Standard Deviation : 0.011094902333537451
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
#
# DecisionTreeClassifier()
#
# Score:  [0.7755102  0.77210884 0.82312925 0.7585034  0.78571429]
# Mean score : 0.7829931972789115
# Standard Deviation : 0.021874741756208904
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
#
# KNeighborsClassifier()
#
# Score:  [0.84693878 0.83333333 0.84693878 0.85034014 0.85714286]
# Mean score : 0.846938775510204
# Standard Deviation : 0.007756295408837643
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦

# %%
#Using some ensemble techniques to boost our model.

#from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier,BaggingClassifier

model=(RandomForestClassifier(),AdaBoostClassifier(),GradientBoostingClassifier(),BaggingClassifier())
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=40)
for i in model:
    print("For model: ",i)
    i.fit(x_train,y_train)
    pred=i.predict(x_test)
    print('Score: ',i.score(x_train,y_train))
    print('Accuracy score: ',accuracy_score(pred,y_test))
    print('Confusion matrix: \n',confusion_matrix(pred,y_test))
    print('classification report: \n',classification_report(pred,y_test))
    print('✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦')
# Out:
# For model:  RandomForestClassifier()
# Score:  1.0
# Accuracy score:  0.8695652173913043
# Confusion matrix:
#  [[310  47]
#  [  1  10]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93       357
#            1       0.18      0.91      0.29        11
#
#     accuracy                           0.87       368
#    macro avg       0.59      0.89      0.61       368
# weighted avg       0.97      0.87      0.91       368
#
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
# For model:  AdaBoostClassifier()
# Score:  0.8974591651542649
# Accuracy score:  0.8885869565217391
# Confusion matrix:
#  [[302  32]
#  [  9  25]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.90      0.94       334
#            1       0.44      0.74      0.55        34
#
#     accuracy                           0.89       368
#    macro avg       0.70      0.82      0.74       368
# weighted avg       0.92      0.89      0.90       368
#
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
# For model:  GradientBoostingClassifier()
# Score:  0.9591651542649727
# Accuracy score:  0.8695652173913043
# Confusion matrix:
#  [[302  39]
#  [  9  18]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.89      0.93       341
#            1       0.32      0.67      0.43        27
#
#     accuracy                           0.87       368
#    macro avg       0.64      0.78      0.68       368
# weighted avg       0.92      0.87      0.89       368
#
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
# For model:  BaggingClassifier()
# Score:  0.9764065335753176
# Accuracy score:  0.8396739130434783
# Confusion matrix:
#  [[297  45]
#  [ 14  12]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.87      0.91       342
#            1       0.21      0.46      0.29        26
#
#     accuracy                           0.84       368
#    macro avg       0.58      0.66      0.60       368
# weighted avg       0.90      0.84      0.87       368
#
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦

# %%
model=[RandomForestClassifier(),AdaBoostClassifier(),GradientBoostingClassifier(),BaggingClassifier()]
for i in model:
    print(i,'\n')
    score=cross_val_score(i,x,y,cv=5,scoring='accuracy')
    print('Score: ',score)
    print('Mean score :',score.mean())
    print('Standard Deviation :',score.std())
    print('✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦\n')
# Out:
# RandomForestClassifier()
#
# Score:  [0.84693878 0.86054422 0.85714286 0.85034014 0.86054422]
# Mean score : 0.8551020408163265
# Standard Deviation : 0.005526556737847565
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
#
# AdaBoostClassifier()
#
# Score:  [0.83673469 0.86734694 0.85714286 0.88435374 0.84013605]
# Mean score : 0.8571428571428571
# Standard Deviation : 0.01760840694631941
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
#
# GradientBoostingClassifier()
#
# Score:  [0.84693878 0.87414966 0.87414966 0.85714286 0.86054422]
# Mean score : 0.8625850340136054
# Standard Deviation : 0.010450538432474276
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
#
# BaggingClassifier()
#
# Score:  [0.84013605 0.85034014 0.85714286 0.83673469 0.8707483 ]
# Mean score : 0.8510204081632653
# Standard Deviation : 0.012244897959183642
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦

# %%
# Using grid searchCV to find out best parameters for different models.

# %%
#For SVC
# from sklearn.model_selection import GridSearchCV
parameters={ 'C' :[1,10],'kernel':['linear','poly','rbf']}
svc=SVC()
clf=GridSearchCV(svc,parameters)
clf.fit(x,y)
print(clf.best_params_)
# Out:
# {'C': 1, 'kernel': 'linear'}

# %%
#For KNeighborsClassifier
parameters={ 'n_neighbors' :[1,10],'weights':['uniform','distance']}
knc=KNeighborsClassifier()
clf=GridSearchCV(knc,parameters)
clf.fit(x,y)
print(clf.best_params_)
# Out:
# {'n_neighbors': 10, 'weights': 'distance'}

# %%
#For RandomForestClassifier
parameters={ 'n_estimators' :[100,200,300],'criterion':['gini','entropy']}
rfc=RandomForestClassifier()
clf=GridSearchCV(rfc,parameters)
clf.fit(x,y)
print(clf.best_params_)
# Out:
# {'criterion': 'entropy', 'n_estimators': 300}

# %%
#For GradientBoostingClassifier
parameters={ 'n_estimators' :[100,200,300],'criterion':['friedman_mse','mse','mae']}
gbc=GradientBoostingClassifier()
clf=GridSearchCV(gbc,parameters)
clf.fit(x,y)
print(clf.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'n_estimators': 100}

# %%
SV=SVC(C=10, kernel='linear')
KN=KNeighborsClassifier(n_neighbors= 10, weights= 'uniform')
RF=RandomForestClassifier(criterion= 'entropy', n_estimators= 300)
GB=GradientBoostingClassifier(criterion='friedman_mse', n_estimators=100)

# %%
models=[]
models.append(('SupportVectorClassifier',SV))
models.append(('KNeighborsClassifier',KN))
models.append(('RandomForestClassifier',RF))
models.append(('GradientBoostingClassifier',GB))

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=40)
Model=[]
Score=[]
CVS=[]
Roc_Score=[]

for name,model in models:
    print(name,':\n')
    Model.append(name)
    
    model.fit(x_train,y_train)
    print(model)
    pred=model.predict(x_test)
    print('\n')
    
    #Accuracy score
    AS=accuracy_score(y_test,pred)
    print('Accuracy Score: ',AS)
    Score.append(AS*100)
    print('\n')
    
    #cross val score
    cross_val=cross_val_score(model,x,y,cv=5,scoring='accuracy').mean()
    print('Cross Val Score: ',cross_val)
    CVS.append(cross_val*100)
    print('\n')
    
    #ROC_AUC_Score
    
    false_positive_rate,true_positive_rate,threshold=roc_curve(y_test,pred)
    roc_auc=auc(false_positive_rate,true_positive_rate)
    print("AUC_ROC_Score",roc_auc)
    Roc_Score.append(roc_auc*100)
    print("\n")
    
    #Confusion Matrix
    cm=confusion_matrix(y_test,pred)
    print(cm)
    print('\n')
    
    #Classification Report
    print("Classification Report: \n",classification_report(y_test,pred))
    print('\n')
    
    #Confusion Matrix using Heatmap
    plt.figure(figsize=(10,10))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True,cbar=False))
    plt.show()
    print('\n')
    
    
    #Auc_Roc_curve
    plt.figure(figsize=(10,25))
    plt.subplot(911)
    plt.title(name)
    plt.plot([0,1],[0,1],'k--')
    plt.plot(false_positive_rate,true_positive_rate,label='AUC=%.2f'%roc_auc)
    plt.legend(loc='Lower Right')
    plt.ylabel('True positive rate')
    plt.xlabel('False positive rate')
    plt.show()
    print('\n')
# Out:
# SupportVectorClassifier :
#
# SVC(C=10, kernel='linear')
#
#
# Accuracy Score:  0.8885869565217391
#
#
# Cross Val Score:  0.8734693877551021
#
#
# AUC_ROC_Score 0.6833361538895469
#
#
# [[305   6]
#  [ 35  22]]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       311
#            1       0.79      0.39      0.52        57
#
#     accuracy                           0.89       368
#    macro avg       0.84      0.68      0.73       368
# weighted avg       0.88      0.89      0.87       368
#
#
#
# AxesSubplot(0.125,0.808774;0.775x0.0712264)
# KNeighborsClassifier :
#
# KNeighborsClassifier(n_neighbors=10)
#
#
# Accuracy Score:  0.8478260869565217
#
#
# Cross Val Score:  0.8448979591836736
#
#
# AUC_ROC_Score 0.5087719298245614
#
#
# [[311   0]
#  [ 56   1]]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92       311
#            1       1.00      0.02      0.03        57
#
#     accuracy                           0.85       368
#    macro avg       0.92      0.51      0.48       368
# weighted avg       0.87      0.85      0.78       368
#
#
#
# AxesSubplot(0.125,0.808774;0.775x0.0712264)
# RandomForestClassifier :
#
# RandomForestClassifier(criterion='entropy', n_estimators=300)
#
#
# Accuracy Score:  0.8722826086956522
#
#
# Cross Val Score:  0.8571428571428571
#
#
# AUC_ROC_Score 0.5877192982456141
#
#
# [[311   0]
#  [ 47  10]]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       311
#            1       1.00      0.18      0.30        57
#
#     accuracy                           0.87       368
#    macro avg       0.93      0.59      0.61       368
# weighted avg       0.89      0.87      0.83       368
#
#
#
# AxesSubplot(0.125,0.808774;0.775x0.0712264)
# GradientBoostingClassifier :
#
# GradientBoostingClassifier()
#
#
# Accuracy Score:  0.8695652173913043
#
#
# Cross Val Score:  0.8619047619047618
#
#
# AUC_ROC_Score 0.6434252834658996
#
#
# [[302   9]
#  [ 39  18]]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93       311
#            1       0.67      0.32      0.43        57
#
#     accuracy                           0.87       368
#    macro avg       0.78      0.64      0.68       368
# weighted avg       0.85      0.87      0.85       368
#
#
#
# AxesSubplot(0.125,0.808774;0.775x0.0712264)

# %%
pd.DataFrame({"Model":Model,"Accuracy Score":Score,'Cross Val Score':CVS,'ROC_AUC_Score':Roc_Score})
# Out:
#                         Model  Accuracy Score  Cross Val Score  ROC_AUC_Score
# 0     SupportVectorClassifier       88.858696        87.346939      68.333615
# 1        KNeighborsClassifier       84.782609        84.489796      50.877193
# 2      RandomForestClassifier       87.228261        85.714286      58.771930
# 3  GradientBoostingClassifier       86.956522        86.190476      64.342528

# %%
#Saving Support Vector Classifier as it is enhancing the performance, also it overcomes over fitting.
import joblib
joblib.dump(SVC,'HR_Attrition.pkl')
# Out:
# ['HR_Attrition.pkl']
