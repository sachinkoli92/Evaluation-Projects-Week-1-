# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
hra=pd.read_csv('hr_analytics.csv')

# %%
hra
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %% [markdown]
# ✏ In this the target varible is Attrition

# %% [markdown]
# # Exploratory Data Analysis

# %%
hra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %% [markdown]
# Mostly columns are of integer type excepy Attrition, Business Travel, Department,EducationField,Gender,JobRole,MaritalStatus,Over18,OverTime.

# %%
hra.shape
# Out:
# (1470, 35)

# %%
#Checking of null values in the data

hra.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
# we see there are no null values in above whole data.

# %%
hra['Gender']
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3       Female
# 4         Male
#          ...
# 1465      Male
# 1466      Male
# 1467      Male
# 1468      Male
# 1469      Male
# Name: Gender, Length: 1470, dtype: object

# %%
for i in hra.columns:
    if hra.dtypes.loc[i]=='object':
        sns.countplot(hra[i])
        plt.xticks(rotation=60)
        plt.show()

# %% [markdown]
# Observations:
#
# 1. In travel there are a huge number of employees who travel rarely for the work.
# 2. In department most of the employees in the data are in the research and development department
# 3. In EducationField there are six education sectors as Life Sciences, Other,Medical,Marketing, Technical Degree,Human Resources. and out of all six maximum persons are from Life Science and minimum are Human Resources.
# 4. In Gender the company has more male employees than female
# 5. In JobRole they are button down in nine ways and the most employees are from Sales Executive.
# 6. In Marital Status we observe three marital status as single, Married and Divorced And Married employee are more in number.
# 7. Over18 is a feature with constant entry for all employees as all the employees are over 18. this column will not help in the Machine Learning.
# 8. Overtime is a feature in which we can observe that employees are not much interested in doing overtime.

# %%
for i in hra. columns:
    if hra.dtypes.loc[i]=='int64':
        hra[i].plot.hist()
        plt.title(i)
        plt.show()

# %% [markdown]
# Observations:
#
# 1. There are several features i.e. DistanceFromHome,JobSatisfaction,MonthlyRate,TotalWorkingYears,PercenSalaryHike,TotalWorkingYears,YearsAtCompany,YearsInCurrentRole etc, are righly skewed. which we have to deal prior to our model fitting.
#
#
# 2. EmployeeNumber and StandardHours are such features which are almost alike to all employees. So these features has nothing to contribute in the target variable.
#
# ================================================================================================================================

# %% [markdown]
# Note: Attrition is a categorical data with yes and no as the entries and for comparing it with other variabless we need to convert attrition categorical data into binary data using Label Encoder.

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
hra['Attrition']=le.fit_transform(hra['Attrition'].astype(str))

# %%
hra
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %% [markdown]
# #Using Attrition as fixed variable comparing with other variables.

# %%
sns.barplot(x='BusinessTravel',y='Attrition',data=hra)

# %% [markdown]
# Number of employees who travel frequently with a higher Attrition Rate.

# %%
sns.barplot(x='Department',y='Attrition',data=hra)

# %% [markdown]
# Sales Department  have a slight higher attrition rate than Human Resources and R&D has the lowewst among of all three department.

# %%
sns.barplot(x='MaritalStatus',y='Attrition',data=hra)

# %% [markdown]
# No of employees who are single are the one with the higher attrition rate among married and Divorced

# %%
sns.barplot(x='OverTime',y='Attrition',data=hra)

# %% [markdown]
# Employees who are working over time can leave the company as they are having higher attrition rate.

# %%
sns.barplot(x='WorkLifeBalance',y='Attrition',data=hra)

# %% [markdown]
# Employee who is having low work life balance lean to have higher attrition rate.

# %%
sns.barplot(x='YearsWithCurrManager',y='Attrition',data=hra)

# %% [markdown]
# No such change can been seen either a employee is with current manager or not they are having a high attrition rate.

# %%
#Statistics analysis

hra.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810     0.161224   802.485714          9.192517     2.912925
# std       9.135373     0.367863   403.509100          8.106864     1.024165
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     0.000000   465.000000          2.000000     2.000000
# 50%      36.000000     0.000000   802.000000          7.000000     3.000000
# 75%      43.000000     0.000000  1157.000000         14.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769    65.891156
# std              0.0      602.024335                 1.093082    20.329428
# min              1.0        1.000000                 1.000000    30.000000
# 25%              1.0      491.250000                 2.000000    48.000000
# 50%              1.0     1020.500000                 3.000000    66.000000
# 75%              1.0     1555.750000                 4.000000    83.750000
# max              1.0     2068.000000                 4.000000   100.000000
#
#        JobInvolvement  ...  RelationshipSatisfaction  StandardHours  \
# count     1470.000000  ...               1470.000000         1470.0
# mean         2.729932  ...                  2.712245           80.0
# std          0.711561  ...                  1.081209            0.0
# min          1.000000  ...                  1.000000           80.0
# 25%          2.000000  ...                  2.000000           80.0
# 50%          3.000000  ...                  3.000000           80.0
# 75%          3.000000  ...                  4.000000           80.0
# max          4.000000  ...                  4.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1470.000000        1470.000000            1470.000000
# mean           0.793878          11.279592               2.799320
# std            0.852077           7.780782               1.289271
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1470.000000           1470.000000
# mean                  2.187755              4.123129
# std                   3.222430              3.568136
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 27 columns]

# %% [markdown]
# After we are describing no of columns we are not visible in the above table. To get a more clear view  of it  lets now draw distplot and boxplot which will tell us skewness and oultiers of the data we have.

# %%
for i in hra.columns:
    if hra.dtypes.loc[i]=='int64':
        sns.distplot(hra[i])
        plt.title(i)
        plt.show()

# %% [markdown]
# Skewed columns:DistanceFromHome, MonthlyIncome, NumCompaniesWorked, PercentSalaryHike, TotalWorkingHours, YearsSinceLastPromotion, YearsAtCompany these features are skewed.

# %%
for i in hra.columns:
    if hra.dtypes.loc[i]=='int64':
        sns.boxplot(hra[i].dropna())
        plt.title(i)
        plt.show()

# %% [markdown]
# Found Outliers in : MonthlyIncome, PercentSalaryHike, TotalWorkingHours, YearsAtCompany, YearsInCurrrentRole, YearsSinceLastPromotion

# %%
# Applying LabelEncoder to convert categorical data

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in hra.columns:
    if hra.dtypes.loc[i]=='object':
        hra[i]=le.fit_transform(hra[i].astype(str))

# %%
hra
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
#       Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0             2               1              1               1  ...
# 1             1               1              1               2  ...
# 2             2               4              1               4  ...
# 3             4               1              1               5  ...
# 4             1               3              1               7  ...
# ...         ...             ...            ...             ...  ...
# 1465          2               3              1            2061  ...
# 1466          1               3              1            2062  ...
# 1467          3               1              1            2064  ...
# 1468          3               3              1            2065  ...
# 1469          3               3              1            2068  ...
#
#       RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                            1             80                 0
# 1                            4             80                 1
# 2                            2             80                 0
# 3                            3             80                 0
# 4                            4             80                 1
# ...                        ...            ...               ...
# 1465                         3             80                 1
# 1466                         1             80                 1
# 1467                         2             80                 1
# 1468                         4             80                 0
# 1469                         1             80                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     8                      0                1
# 1                    10                      3                3
# 2                     7                      3                3
# 3                     8                      3                3
# 4                     6                      3                3
# ...                 ...                    ...              ...
# 1465                 17                      3                3
# 1466                  9                      5                3
# 1467                  6                      0                3
# 1468                 17                      3                2
# 1469                  6                      3                4
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                  6                   4                        0
# 1                 10                   7                        1
# 2                  0                   0                        0
# 3                  8                   7                        3
# 4                  2                   2                        2
# ...              ...                 ...                      ...
# 1465               5                   2                        0
# 1466               7                   7                        1
# 1467               6                   2                        0
# 1468               9                   6                        0
# 1469               4                   3                        1
#
#       YearsWithCurrManager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
# ...                    ...
# 1465                     3
# 1466                     7
# 1467                     3
# 1468                     8
# 1469                     2
#
# [1470 rows x 35 columns]

# %% [markdown]
# Dropping the features with constant entry i.e. Over18, StandardHours, EmployeeCount.

# %%
hra.drop(['Over18','StandardHours','EmployeeCount'],axis=1,inplace=True)

# %%
hra
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
#       Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  ...  \
# 0             2               1               1                        2  ...
# 1             1               1               2                        3  ...
# 2             2               4               4                        4  ...
# 3             4               1               5                        4  ...
# 4             1               3               7                        1  ...
# ...         ...             ...             ...                      ...  ...
# 1465          2               3            2061                        3  ...
# 1466          1               3            2062                        4  ...
# 1467          3               1            2064                        2  ...
# 1468          3               3            2065                        4  ...
# 1469          3               3            2068                        2  ...
#
#       PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                     3                         1                 0
# 1                     4                         4                 1
# 2                     3                         2                 0
# 3                     3                         3                 0
# 4                     3                         4                 1
# ...                 ...                       ...               ...
# 1465                  3                         3                 1
# 1466                  3                         1                 1
# 1467                  4                         2                 1
# 1468                  3                         4                 0
# 1469                  3                         1                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     8                      0                1
# 1                    10                      3                3
# 2                     7                      3                3
# 3                     8                      3                3
# 4                     6                      3                3
# ...                 ...                    ...              ...
# 1465                 17                      3                3
# 1466                  9                      5                3
# 1467                  6                      0                3
# 1468                 17                      3                2
# 1469                  6                      3                4
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                  6                   4                        0
# 1                 10                   7                        1
# 2                  0                   0                        0
# 3                  8                   7                        3
# 4                  2                   2                        2
# ...              ...                 ...                      ...
# 1465               5                   2                        0
# 1466               7                   7                        1
# 1467               6                   2                        0
# 1468               9                   6                        0
# 1469               4                   3                        1
#
#       YearsWithCurrManager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
# ...                    ...
# 1465                     3
# 1466                     7
# 1467                     3
# 1468                     8
# 1469                     2
#
# [1470 rows x 32 columns]

# %%
hra.corr()
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159205        0.024751   0.010661
# Attrition                -0.159205   1.000000        0.000074  -0.056652
# BusinessTravel            0.024751   0.000074        1.000000  -0.004086
# DailyRate                 0.010661  -0.056652       -0.004086   1.000000
# Department               -0.031882   0.063991       -0.009044   0.007109
# DistanceFromHome         -0.001686   0.077924       -0.024469  -0.004985
# Education                 0.208034  -0.031373        0.000757  -0.016806
# EducationField           -0.040873   0.026846        0.023724   0.037709
# EmployeeNumber           -0.010145  -0.010577       -0.015578  -0.050990
# EnvironmentSatisfaction   0.010146  -0.103369        0.004174   0.018355
# Gender                   -0.036311   0.029453       -0.032981  -0.011716
# HourlyRate                0.024287  -0.006846        0.026528   0.023381
# JobInvolvement            0.029820  -0.130016        0.039062   0.046135
# JobLevel                  0.509604  -0.169105        0.019311   0.002966
# JobRole                  -0.122427   0.067151        0.002724  -0.009472
# JobSatisfaction          -0.004892  -0.103481       -0.033962   0.030571
# MaritalStatus            -0.095029   0.162070        0.024001  -0.069586
# MonthlyIncome             0.497855  -0.159840        0.034319   0.007707
# MonthlyRate               0.028051   0.015170       -0.014107  -0.032182
# NumCompaniesWorked        0.299635   0.043494        0.020875   0.038153
# OverTime                  0.028062   0.246118        0.016543   0.009135
# PercentSalaryHike         0.003634  -0.013478       -0.029377   0.022704
# PerformanceRating         0.001904   0.002889       -0.026341   0.000473
# RelationshipSatisfaction  0.053535  -0.045872       -0.035986   0.007846
# StockOptionLevel          0.037510  -0.137145       -0.016727   0.042143
# TotalWorkingYears         0.680381  -0.171063        0.034226   0.014515
# TrainingTimesLastYear    -0.019621  -0.059478        0.015240   0.002453
# WorkLifeBalance          -0.021490  -0.063939       -0.011256  -0.037848
# YearsAtCompany            0.311309  -0.134392       -0.014575  -0.034055
# YearsInCurrentRole        0.212901  -0.160545       -0.011497   0.009932
# YearsSinceLastPromotion   0.216513  -0.033019       -0.032591  -0.033229
# YearsWithCurrManager      0.202089  -0.156199       -0.022636  -0.026363
#
#                           Department  DistanceFromHome  Education  \
# Age                        -0.031882         -0.001686   0.208034
# Attrition                   0.063991          0.077924  -0.031373
# BusinessTravel             -0.009044         -0.024469   0.000757
# DailyRate                   0.007109         -0.004985  -0.016806
# Department                  1.000000          0.017225   0.007996
# DistanceFromHome            0.017225          1.000000   0.021042
# Education                   0.007996          0.021042   1.000000
# EducationField              0.013720          0.002013  -0.039592
# EmployeeNumber             -0.010895          0.032916   0.042070
# EnvironmentSatisfaction    -0.019395         -0.016075  -0.027128
# Gender                     -0.041583         -0.001851  -0.016547
# HourlyRate                 -0.004144          0.031131   0.016775
# JobInvolvement             -0.024586          0.008783   0.042438
# JobLevel                    0.101963          0.005303   0.101589
# JobRole                     0.662431         -0.001015   0.004236
# JobSatisfaction             0.021001         -0.003669  -0.011296
# MaritalStatus               0.056073         -0.014437   0.004053
# MonthlyIncome               0.053130         -0.017014   0.094961
# MonthlyRate                 0.023642          0.027473  -0.026084
# NumCompaniesWorked         -0.035882         -0.029251   0.126317
# OverTime                    0.007481          0.025514  -0.020322
# PercentSalaryHike          -0.007840          0.040235  -0.011111
# PerformanceRating          -0.024604          0.027110  -0.024539
# RelationshipSatisfaction   -0.022414          0.006557  -0.009118
# StockOptionLevel           -0.012193          0.044872   0.018422
# TotalWorkingYears          -0.015762          0.004628   0.148280
# TrainingTimesLastYear       0.036875         -0.036942  -0.025100
# WorkLifeBalance             0.026383         -0.026556   0.009819
# YearsAtCompany              0.022920          0.009508   0.069114
# YearsInCurrentRole          0.056315          0.018845   0.060236
# YearsSinceLastPromotion     0.040061          0.010029   0.054254
# YearsWithCurrManager        0.034282          0.014406   0.069065
#
#                           EducationField  EmployeeNumber  \
# Age                            -0.040873       -0.010145
# Attrition                       0.026846       -0.010577
# BusinessTravel                  0.023724       -0.015578
# DailyRate                       0.037709       -0.050990
# Department                      0.013720       -0.010895
# DistanceFromHome                0.002013        0.032916
# Education                      -0.039592        0.042070
# EducationField                  1.000000       -0.002516
# EmployeeNumber                 -0.002516        1.000000
# EnvironmentSatisfaction         0.043163        0.017621
# Gender                         -0.002504        0.022556
# HourlyRate                     -0.021941        0.035179
# JobInvolvement                 -0.002655       -0.006888
# JobLevel                       -0.044933       -0.018519
# JobRole                         0.015599       -0.010336
# JobSatisfaction                -0.034401       -0.046247
# MaritalStatus                   0.014420       -0.008155
# MonthlyIncome                  -0.041070       -0.014829
# MonthlyRate                    -0.027182        0.012648
# NumCompaniesWorked             -0.008663       -0.001251
# OverTime                        0.002259       -0.024037
# PercentSalaryHike              -0.011214       -0.012944
# PerformanceRating              -0.005614       -0.020359
# RelationshipSatisfaction       -0.004378       -0.069861
# StockOptionLevel               -0.016185        0.062227
# TotalWorkingYears              -0.027848       -0.014365
# TrainingTimesLastYear           0.049195        0.023603
# WorkLifeBalance                 0.041191        0.010309
# YearsAtCompany                 -0.018692       -0.011240
# YearsInCurrentRole             -0.010506       -0.008416
# YearsSinceLastPromotion         0.002326       -0.009019
# YearsWithCurrManager           -0.004130       -0.009197
#
#                           EnvironmentSatisfaction  ...  PerformanceRating  \
# Age                                      0.010146  ...           0.001904
# Attrition                               -0.103369  ...           0.002889
# BusinessTravel                           0.004174  ...          -0.026341
# DailyRate                                0.018355  ...           0.000473
# Department                              -0.019395  ...          -0.024604
# DistanceFromHome                        -0.016075  ...           0.027110
# Education                               -0.027128  ...          -0.024539
# EducationField                           0.043163  ...          -0.005614
# EmployeeNumber                           0.017621  ...          -0.020359
# EnvironmentSatisfaction                  1.000000  ...          -0.029548
# Gender                                   0.000508  ...          -0.013859
# HourlyRate                              -0.049857  ...          -0.002172
# JobInvolvement                          -0.008278  ...          -0.029071
# JobLevel                                 0.001212  ...          -0.021222
# JobRole                                 -0.017321  ...          -0.024233
# JobSatisfaction                         -0.006784  ...           0.002297
# MaritalStatus                           -0.003593  ...           0.005207
# MonthlyIncome                           -0.006259  ...          -0.017120
# MonthlyRate                              0.037600  ...          -0.009811
# NumCompaniesWorked                       0.012594  ...          -0.014095
# OverTime                                 0.070132  ...           0.004369
# PercentSalaryHike                       -0.031701  ...           0.773550
# PerformanceRating                       -0.029548  ...           1.000000
# RelationshipSatisfaction                 0.007665  ...          -0.031351
# StockOptionLevel                         0.003432  ...           0.003506
# TotalWorkingYears                       -0.002693  ...           0.006744
# TrainingTimesLastYear                   -0.019359  ...          -0.015579
# WorkLifeBalance                          0.027627  ...           0.002572
# YearsAtCompany                           0.001458  ...           0.003435
# YearsInCurrentRole                       0.018007  ...           0.034986
# YearsSinceLastPromotion                  0.016194  ...           0.017896
# YearsWithCurrManager                    -0.004999  ...           0.022827
#
#                           RelationshipSatisfaction  StockOptionLevel  \
# Age                                       0.053535          0.037510
# Attrition                                -0.045872         -0.137145
# BusinessTravel                           -0.035986         -0.016727
# DailyRate                                 0.007846          0.042143
# Department                               -0.022414         -0.012193
# DistanceFromHome                          0.006557          0.044872
# Education                                -0.009118          0.018422
# EducationField                           -0.004378         -0.016185
# EmployeeNumber                           -0.069861          0.062227
# EnvironmentSatisfaction                   0.007665          0.003432
# Gender                                    0.022868          0.012716
# HourlyRate                                0.001330          0.050263
# JobInvolvement                            0.034297          0.021523
# JobLevel                                  0.021642          0.013984
# JobRole                                  -0.020218         -0.019171
# JobSatisfaction                          -0.012454          0.010690
# MaritalStatus                             0.022549         -0.662577
# MonthlyIncome                             0.025873          0.005408
# MonthlyRate                              -0.004085         -0.034323
# NumCompaniesWorked                        0.052733          0.030075
# OverTime                                  0.048493         -0.000449
# PercentSalaryHike                        -0.040490          0.007528
# PerformanceRating                        -0.031351          0.003506
# RelationshipSatisfaction                  1.000000         -0.045952
# StockOptionLevel                         -0.045952          1.000000
# TotalWorkingYears                         0.024054          0.010136
# TrainingTimesLastYear                     0.002497          0.011274
# WorkLifeBalance                           0.019604          0.004129
# YearsAtCompany                            0.019367          0.015058
# YearsInCurrentRole                       -0.015123          0.050818
# YearsSinceLastPromotion                   0.033493          0.014352
# YearsWithCurrManager                     -0.000867          0.024698
#
#                           TotalWorkingYears  TrainingTimesLastYear  \
# Age                                0.680381              -0.019621
# Attrition                         -0.171063              -0.059478
# BusinessTravel                     0.034226               0.015240
# DailyRate                          0.014515               0.002453
# Department                        -0.015762               0.036875
# DistanceFromHome                   0.004628              -0.036942
# Education                          0.148280              -0.025100
# EducationField                    -0.027848               0.049195
# EmployeeNumber                    -0.014365               0.023603
# EnvironmentSatisfaction           -0.002693              -0.019359
# Gender                            -0.046881              -0.038787
# HourlyRate                        -0.002334              -0.008548
# JobInvolvement                    -0.005533              -0.015338
# JobLevel                           0.782208              -0.018191
# JobRole                           -0.145439               0.001342
# JobSatisfaction                   -0.020185              -0.005779
# MaritalStatus                     -0.077886               0.010629
# MonthlyIncome                      0.772893              -0.021736
# MonthlyRate                        0.026442               0.001467
# NumCompaniesWorked                 0.237639              -0.066054
# OverTime                           0.012754              -0.079113
# PercentSalaryHike                 -0.020608              -0.005221
# PerformanceRating                  0.006744              -0.015579
# RelationshipSatisfaction           0.024054               0.002497
# StockOptionLevel                   0.010136               0.011274
# TotalWorkingYears                  1.000000              -0.035662
# TrainingTimesLastYear             -0.035662               1.000000
# WorkLifeBalance                    0.001008               0.028072
# YearsAtCompany                     0.628133               0.003569
# YearsInCurrentRole                 0.460365              -0.005738
# YearsSinceLastPromotion            0.404858              -0.002067
# YearsWithCurrManager               0.459188              -0.004096
#
#                           WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# Age                             -0.021490        0.311309            0.212901
# Attrition                       -0.063939       -0.134392           -0.160545
# BusinessTravel                  -0.011256       -0.014575           -0.011497
# DailyRate                       -0.037848       -0.034055            0.009932
# Department                       0.026383        0.022920            0.056315
# DistanceFromHome                -0.026556        0.009508            0.018845
# Education                        0.009819        0.069114            0.060236
# EducationField                   0.041191       -0.018692           -0.010506
# EmployeeNumber                   0.010309       -0.011240           -0.008416
# EnvironmentSatisfaction          0.027627        0.001458            0.018007
# Gender                          -0.002753       -0.029747           -0.041483
# HourlyRate                      -0.004607       -0.019582           -0.024106
# JobInvolvement                  -0.014617       -0.021355            0.008717
# JobLevel                         0.037818        0.534739            0.389447
# JobRole                          0.027764       -0.083657           -0.028354
# JobSatisfaction                 -0.019459       -0.003803           -0.002305
# MaritalStatus                    0.014708       -0.059986           -0.065822
# MonthlyIncome                    0.030683        0.514285            0.363818
# MonthlyRate                      0.007963       -0.023655           -0.012815
# NumCompaniesWorked              -0.008366       -0.118421           -0.090754
# OverTime                        -0.027092       -0.011687           -0.029758
# PercentSalaryHike               -0.003280       -0.035991           -0.001520
# PerformanceRating                0.002572        0.003435            0.034986
# RelationshipSatisfaction         0.019604        0.019367           -0.015123
# StockOptionLevel                 0.004129        0.015058            0.050818
# TotalWorkingYears                0.001008        0.628133            0.460365
# TrainingTimesLastYear            0.028072        0.003569           -0.005738
# WorkLifeBalance                  1.000000        0.012089            0.049856
# YearsAtCompany                   0.012089        1.000000            0.758754
# YearsInCurrentRole               0.049856        0.758754            1.000000
# YearsSinceLastPromotion          0.008941        0.618409            0.548056
# YearsWithCurrManager             0.002759        0.769212            0.714365
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                      0.216513              0.202089
# Attrition                               -0.033019             -0.156199
# BusinessTravel                          -0.032591             -0.022636
# DailyRate                               -0.033229             -0.026363
# Department                               0.040061              0.034282
# DistanceFromHome                         0.010029              0.014406
# Education                                0.054254              0.069065
# EducationField                           0.002326             -0.004130
# EmployeeNumber                          -0.009019             -0.009197
# EnvironmentSatisfaction                  0.016194             -0.004999
# Gender                                  -0.026985             -0.030599
# HourlyRate                              -0.026716             -0.020123
# JobInvolvement                          -0.024184              0.025976
# JobLevel                                 0.353885              0.375281
# JobRole                                 -0.046384             -0.041150
# JobSatisfaction                         -0.018214             -0.027656
# MaritalStatus                           -0.030915             -0.038570
# MonthlyIncome                            0.344978              0.344079
# MonthlyRate                              0.001567             -0.036746
# NumCompaniesWorked                      -0.036814             -0.110319
# OverTime                                -0.012239             -0.041586
# PercentSalaryHike                       -0.022154             -0.011985
# PerformanceRating                        0.017896              0.022827
# RelationshipSatisfaction                 0.033493             -0.000867
# StockOptionLevel                         0.014352              0.024698
# TotalWorkingYears                        0.404858              0.459188
# TrainingTimesLastYear                   -0.002067             -0.004096
# WorkLifeBalance                          0.008941              0.002759
# YearsAtCompany                           0.618409              0.769212
# YearsInCurrentRole                       0.548056              0.714365
# YearsSinceLastPromotion                  1.000000              0.510224
# YearsWithCurrManager                     0.510224              1.000000
#
# [32 rows x 32 columns]

# %%
plt.figure(figsize=(15,15))
sns.heatmap(hra.corr(),cmap='cividis')

# %% [markdown]
# Observations:
#
# 1. Attrition has a negative correlaton with age.
# 2. percent salary hike,performancerating are positively correlated.
# 3. YearsInCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager are positively correlated with each other.

# %%
# Checking skewness

hra.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome            0.958118
# Education                  -0.289681
# EducationField              0.550371
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# YearsWithCurrManager        0.833451
# dtype: float64

# %%
# Removing skewness using Log Transform.
for i in hra.columns:
    if hra.skew().loc[i]>0.55:
        hra[i]=le.fit_transform(hra[i].astype(str))

# %%
hra.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome           -0.070955
# Education                  -0.289681
# EducationField              0.550371
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               0.009778
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           0.095256
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany             -0.166139
# YearsInCurrentRole         -0.670382
# YearsSinceLastPromotion     0.924140
# YearsWithCurrManager       -0.529429
# dtype: float64

# %%
#Removing outliers
from scipy.stats import zscore
z=np.abs(zscore(hra))

# %%
hras=hra[(z<3).all(axis=1)]

# %%
hras
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 0
# 1      49          0               1        279           1                27
# 2      37          1               2       1373           1                11
# 3      33          0               1       1392           1                22
# 4      27          0               2        591           1                11
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                15
# 1466   39          0               2        613           1                25
# 1467   27          0               2        155           1                23
# 1468   49          0               1       1023           2                11
# 1469   34          0               2        628           1                27
#
#       Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  ...  \
# 0             2               1               1                        2  ...
# 1             1               1               2                        3  ...
# 2             2               4               4                        4  ...
# 3             4               1               5                        4  ...
# 4             1               3               7                        1  ...
# ...         ...             ...             ...                      ...  ...
# 1465          2               3            2061                        3  ...
# 1466          1               3            2062                        4  ...
# 1467          3               1            2064                        2  ...
# 1468          3               3            2065                        4  ...
# 1469          3               3            2068                        2  ...
#
#       PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                     0                         1                 0
# 1                     1                         4                 1
# 2                     0                         2                 0
# 3                     0                         3                 0
# 4                     0                         4                 1
# ...                 ...                       ...               ...
# 1465                  0                         3                 1
# 1466                  0                         1                 1
# 1467                  1                         2                 1
# 1468                  0                         4                 0
# 1469                  0                         1                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                    38                      0                1
# 1                     2                      3                3
# 2                    37                      3                3
# 3                    38                      3                3
# 4                    36                      3                3
# ...                 ...                    ...              ...
# 1465                  9                      3                3
# 1466                 39                      5                3
# 1467                 36                      0                3
# 1468                  9                      3                2
# 1469                 36                      3                4
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                 33                  13                        0
# 1                  2                  16                        1
# 2                  0                   0                        0
# 3                 35                  16                        9
# 4                 12                  11                        8
# ...              ...                 ...                      ...
# 1465              32                  11                        0
# 1466              34                  16                        1
# 1467              33                  11                        0
# 1468              36                  15                        0
# 1469              30                  12                        1
#
#       YearsWithCurrManager
# 0                       13
# 1                       15
# 2                        0
# 3                        0
# 4                       10
# ...                    ...
# 1465                    11
# 1466                    15
# 1467                    11
# 1468                    16
# 1469                    10
#
# [1470 rows x 32 columns]

# %%
print('Shape before removing outliers:',hra.shape)
print('Shape after removing outliers: ',hras.shape)
# Out:
# Shape before removing outliers: (1470, 32)
# Shape after removing outliers:  (1470, 32)

# %%
hras.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome           -0.070955
# Education                  -0.289681
# EducationField              0.550371
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               0.009778
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           0.095256
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany             -0.166139
# YearsInCurrentRole         -0.670382
# YearsSinceLastPromotion     0.924140
# YearsWithCurrManager       -0.529429
# dtype: float64

# %%
x=hras.drop(['Attrition'],axis=1)
x
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               2       1102           2                 0          2
# 1      49               1        279           1                27          1
# 2      37               2       1373           1                11          2
# 3      33               1       1392           1                22          4
# 4      27               2        591           1                11          1
# ...   ...             ...        ...         ...               ...        ...
# 1465   36               1        884           1                15          2
# 1466   39               2        613           1                25          1
# 1467   27               2        155           1                23          3
# 1468   49               1       1023           2                11          3
# 1469   34               2        628           1                27          3
#
#       EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  ...  \
# 0                  1               1                        2       0  ...
# 1                  1               2                        3       1  ...
# 2                  4               4                        4       1  ...
# 3                  1               5                        4       0  ...
# 4                  3               7                        1       1  ...
# ...              ...             ...                      ...     ...  ...
# 1465               3            2061                        3       1  ...
# 1466               3            2062                        4       1  ...
# 1467               1            2064                        2       1  ...
# 1468               3            2065                        4       1  ...
# 1469               3            2068                        2       1  ...
#
#       PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                     0                         1                 0
# 1                     1                         4                 1
# 2                     0                         2                 0
# 3                     0                         3                 0
# 4                     0                         4                 1
# ...                 ...                       ...               ...
# 1465                  0                         3                 1
# 1466                  0                         1                 1
# 1467                  1                         2                 1
# 1468                  0                         4                 0
# 1469                  0                         1                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                    38                      0                1
# 1                     2                      3                3
# 2                    37                      3                3
# 3                    38                      3                3
# 4                    36                      3                3
# ...                 ...                    ...              ...
# 1465                  9                      3                3
# 1466                 39                      5                3
# 1467                 36                      0                3
# 1468                  9                      3                2
# 1469                 36                      3                4
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                 33                  13                        0
# 1                  2                  16                        1
# 2                  0                   0                        0
# 3                 35                  16                        9
# 4                 12                  11                        8
# ...              ...                 ...                      ...
# 1465              32                  11                        0
# 1466              34                  16                        1
# 1467              33                  11                        0
# 1468              36                  15                        0
# 1469              30                  12                        1
#
#       YearsWithCurrManager
# 0                       13
# 1                       15
# 2                        0
# 3                        0
# 4                       10
# ...                    ...
# 1465                    11
# 1466                    15
# 1467                    11
# 1468                    16
# 1469                    10
#
# [1470 rows x 31 columns]

# %%
y=hr_new['Attrition']
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int32

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
xx=sc.fit_transform(x)
x=pd.DataFrame(xx,columns=x.columns)

# %%
x
# Out:
#            Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0     0.446350        0.590048   0.742527    1.401512         -1.422389
# 1     1.322365       -0.913194  -1.297775   -0.493817          1.323191
# 2     0.008343        0.590048   1.414363   -0.493817         -0.303819
# 3    -0.429664       -0.913194   1.461466   -0.493817          0.814750
# 4    -1.086676        0.590048  -0.524295   -0.493817         -0.303819
# ...        ...             ...        ...         ...               ...
# 1465 -0.101159       -0.913194   0.202082   -0.493817          0.102933
# 1466  0.227347        0.590048  -0.469754   -0.493817          1.119815
# 1467 -1.086676        0.590048  -1.605183   -0.493817          0.916438
# 1468  1.322365       -0.913194   0.546677    1.401512         -0.303819
# 1469 -0.320163        0.590048  -0.432568   -0.493817          1.323191
#
#       Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# 0     -0.891688       -0.937414       -1.701283                -0.660531
# 1     -1.868426       -0.937414       -1.699621                 0.254625
# 2     -0.891688        1.316673       -1.696298                 1.169781
# 3      1.061787       -0.937414       -1.694636                 1.169781
# 4     -1.868426        0.565311       -1.691313                -1.575686
# ...         ...             ...             ...                      ...
# 1465  -0.891688        0.565311        1.721670                 0.254625
# 1466  -1.868426        0.565311        1.723332                 1.169781
# 1467   0.085049       -0.937414        1.726655                -0.660531
# 1468   0.085049        0.565311        1.728317                 1.169781
# 1469   0.085049        0.565311        1.733302                -0.660531
#
#         Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 0    -1.224745  ...          -0.426230                 -1.584178
# 1     0.816497  ...           2.346151                  1.191438
# 2     0.816497  ...          -0.426230                 -0.658973
# 3    -1.224745  ...          -0.426230                  0.266233
# 4     0.816497  ...          -0.426230                  1.191438
# ...        ...  ...                ...                       ...
# 1465  0.816497  ...          -0.426230                  0.266233
# 1466  0.816497  ...          -0.426230                 -1.584178
# 1467  0.816497  ...           2.346151                 -0.658973
# 1468  0.816497  ...          -0.426230                  1.191438
# 1469  0.816497  ...          -0.426230                 -1.584178
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0            -0.932014           1.255887              -2.171982
# 1             0.241988          -1.186295               0.155707
# 2            -0.932014           1.188048               0.155707
# 3            -0.932014           1.255887               0.155707
# 4             0.241988           1.120210               0.155707
# ...                ...                ...                    ...
# 1465          0.241988          -0.711426               0.155707
# 1466          0.241988           1.323725               1.707500
# 1467          0.241988           1.120210              -2.171982
# 1468         -0.932014          -0.711426               0.155707
# 1469         -0.932014           1.120210               0.155707
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0           -2.493820        1.025396            0.475267
# 1            0.338096       -1.271915            0.975369
# 2            0.338096       -1.420129           -1.691842
# 3            0.338096        1.173610            0.975369
# 4            0.338096       -0.530847            0.141866
# ...               ...             ...                 ...
# 1465         0.338096        0.951290            0.141866
# 1466         0.338096        1.099503            0.975369
# 1467         0.338096        1.025396            0.141866
# 1468        -1.077862        1.247717            0.808669
# 1469         1.754054        0.803076            0.308566
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                   -0.776855              0.659274
# 1                   -0.565378              1.005331
# 2                   -0.776855             -1.590097
# 3                    1.126440             -1.590097
# 4                    0.914963              0.140188
# ...                       ...                   ...
# 1465                -0.776855              0.313217
# 1466                -0.565378              1.005331
# 1467                -0.776855              0.313217
# 1468                -0.776855              1.178360
# 1469                -0.565378              0.140188
#
# [1470 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report

# %%
list=[LogisticRegression(),GaussianNB(),SVC(),DecisionTreeClassifier(),KNeighborsClassifier()]
for g in list:
    r_max=0
    print('for the algorithm: ',g)
    for i in range(33,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=i)
        g.fit(x_train,y_train)
        pred=g.predict(x_test)
        accuracy=accuracy_score(pred,y_test)
        print('accuracy score corresponding to random state',i,'is: ',accuracy)
        if accuracy>r_max:
            r_max=accuracy
            final=i
    print('\n')
    print('Max accuracy score corresponding to: ', final,'is: ',r_max)
    print('✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦')
    print('\n')
# Out:
# for the algorithm:  LogisticRegression()
# accuracy score corresponding to random state 33 is:  0.8614130434782609
# accuracy score corresponding to random state 34 is:  0.8722826086956522
# accuracy score corresponding to random state 35 is:  0.8967391304347826
# accuracy score corresponding to random state 36 is:  0.8804347826086957
# accuracy score corresponding to random state 37 is:  0.8722826086956522
# accuracy score corresponding to random state 38 is:  0.875
# accuracy score corresponding to random state 39 is:  0.8722826086956522
# accuracy score corresponding to random state 40 is:  0.904891304347826
# accuracy score corresponding to random state 41 is:  0.8831521739130435
# accuracy score corresponding to random state 42 is:  0.8858695652173914
# accuracy score corresponding to random state 43 is:  0.8614130434782609
# accuracy score corresponding to random state 44 is:  0.8858695652173914
# accuracy score corresponding to random state 45 is:  0.8505434782608695
# accuracy score corresponding to random state 46 is:  0.8695652173913043
# accuracy score corresponding to random state 47 is:  0.8858695652173914
# accuracy score corresponding to random state 48 is:  0.8614130434782609
# accuracy score corresponding to random state 49 is:  0.8777173913043478
# accuracy score corresponding to random state 50 is:  0.8695652173913043
# accuracy score corresponding to random state 51 is:  0.8885869565217391
# accuracy score corresponding to random state 52 is:  0.8695652173913043
# accuracy score corresponding to random state 53 is:  0.8858695652173914
# accuracy score corresponding to random state 54 is:  0.8614130434782609
# accuracy score corresponding to random state 55 is:  0.8940217391304348
# accuracy score corresponding to random state 56 is:  0.8559782608695652
# accuracy score corresponding to random state 57 is:  0.8804347826086957
# accuracy score corresponding to random state 58 is:  0.8505434782608695
# accuracy score corresponding to random state 59 is:  0.8831521739130435
# accuracy score corresponding to random state 60 is:  0.8722826086956522
# accuracy score corresponding to random state 61 is:  0.8641304347826086
# accuracy score corresponding to random state 62 is:  0.8586956521739131
# accuracy score corresponding to random state 63 is:  0.8831521739130435
# accuracy score corresponding to random state 64 is:  0.8804347826086957
# accuracy score corresponding to random state 65 is:  0.8586956521739131
# accuracy score corresponding to random state 66 is:  0.8641304347826086
# accuracy score corresponding to random state 67 is:  0.8777173913043478
# accuracy score corresponding to random state 68 is:  0.8342391304347826
# accuracy score corresponding to random state 69 is:  0.8396739130434783
# accuracy score corresponding to random state 70 is:  0.8505434782608695
# accuracy score corresponding to random state 71 is:  0.8722826086956522
# accuracy score corresponding to random state 72 is:  0.8614130434782609
# accuracy score corresponding to random state 73 is:  0.8885869565217391
# accuracy score corresponding to random state 74 is:  0.8559782608695652
# accuracy score corresponding to random state 75 is:  0.8288043478260869
# accuracy score corresponding to random state 76 is:  0.8641304347826086
# accuracy score corresponding to random state 77 is:  0.8777173913043478
# accuracy score corresponding to random state 78 is:  0.875
# accuracy score corresponding to random state 79 is:  0.8342391304347826
# accuracy score corresponding to random state 80 is:  0.8722826086956522
# accuracy score corresponding to random state 81 is:  0.8804347826086957
# accuracy score corresponding to random state 82 is:  0.875
# accuracy score corresponding to random state 83 is:  0.8913043478260869
# accuracy score corresponding to random state 84 is:  0.8831521739130435
# accuracy score corresponding to random state 85 is:  0.8831521739130435
# accuracy score corresponding to random state 86 is:  0.8913043478260869
# accuracy score corresponding to random state 87 is:  0.8505434782608695
# accuracy score corresponding to random state 88 is:  0.8478260869565217
# accuracy score corresponding to random state 89 is:  0.8695652173913043
# accuracy score corresponding to random state 90 is:  0.8641304347826086
# accuracy score corresponding to random state 91 is:  0.8831521739130435
# accuracy score corresponding to random state 92 is:  0.875
# accuracy score corresponding to random state 93 is:  0.8994565217391305
# accuracy score corresponding to random state 94 is:  0.8695652173913043
# accuracy score corresponding to random state 95 is:  0.8777173913043478
# accuracy score corresponding to random state 96 is:  0.8695652173913043
# accuracy score corresponding to random state 97 is:  0.8722826086956522
# accuracy score corresponding to random state 98 is:  0.8777173913043478
# accuracy score corresponding to random state 99 is:  0.8641304347826086
# accuracy score corresponding to random state 100 is:  0.8641304347826086
#
#
# Max accuracy score corresponding to:  40 is:  0.904891304347826
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
#
#
# for the algorithm:  GaussianNB()
# accuracy score corresponding to random state 33 is:  0.8478260869565217
# accuracy score corresponding to random state 34 is:  0.8396739130434783
# accuracy score corresponding to random state 35 is:  0.8478260869565217
# accuracy score corresponding to random state 36 is:  0.8641304347826086
# accuracy score corresponding to random state 37 is:  0.8586956521739131
# accuracy score corresponding to random state 38 is:  0.8532608695652174
# accuracy score corresponding to random state 39 is:  0.8668478260869565
# accuracy score corresponding to random state 40 is:  0.8695652173913043
# accuracy score corresponding to random state 41 is:  0.8695652173913043
# accuracy score corresponding to random state 42 is:  0.8315217391304348
# accuracy score corresponding to random state 43 is:  0.8369565217391305
# accuracy score corresponding to random state 44 is:  0.8505434782608695
# accuracy score corresponding to random state 45 is:  0.8396739130434783
# accuracy score corresponding to random state 46 is:  0.8342391304347826
# accuracy score corresponding to random state 47 is:  0.8260869565217391
# accuracy score corresponding to random state 48 is:  0.8641304347826086
# accuracy score corresponding to random state 49 is:  0.8532608695652174
# accuracy score corresponding to random state 50 is:  0.845108695652174
# accuracy score corresponding to random state 51 is:  0.8641304347826086
# accuracy score corresponding to random state 52 is:  0.8668478260869565
# accuracy score corresponding to random state 53 is:  0.8641304347826086
# accuracy score corresponding to random state 54 is:  0.842391304347826
# accuracy score corresponding to random state 55 is:  0.8641304347826086
# accuracy score corresponding to random state 56 is:  0.8369565217391305
# accuracy score corresponding to random state 57 is:  0.842391304347826
# accuracy score corresponding to random state 58 is:  0.8152173913043478
# accuracy score corresponding to random state 59 is:  0.8831521739130435
# accuracy score corresponding to random state 60 is:  0.8315217391304348
# accuracy score corresponding to random state 61 is:  0.8233695652173914
# accuracy score corresponding to random state 62 is:  0.8478260869565217
# accuracy score corresponding to random state 63 is:  0.8396739130434783
# accuracy score corresponding to random state 64 is:  0.8505434782608695
# accuracy score corresponding to random state 65 is:  0.8206521739130435
# accuracy score corresponding to random state 66 is:  0.8532608695652174
# accuracy score corresponding to random state 67 is:  0.8777173913043478
# accuracy score corresponding to random state 68 is:  0.8043478260869565
# accuracy score corresponding to random state 69 is:  0.8233695652173914
# accuracy score corresponding to random state 70 is:  0.8478260869565217
# accuracy score corresponding to random state 71 is:  0.8152173913043478
# accuracy score corresponding to random state 72 is:  0.8478260869565217
# accuracy score corresponding to random state 73 is:  0.8614130434782609
# accuracy score corresponding to random state 74 is:  0.7880434782608695
# accuracy score corresponding to random state 75 is:  0.8125
# accuracy score corresponding to random state 76 is:  0.8315217391304348
# accuracy score corresponding to random state 77 is:  0.8315217391304348
# accuracy score corresponding to random state 78 is:  0.8641304347826086
# accuracy score corresponding to random state 79 is:  0.8315217391304348
# accuracy score corresponding to random state 80 is:  0.8505434782608695
# accuracy score corresponding to random state 81 is:  0.8804347826086957
# accuracy score corresponding to random state 82 is:  0.8505434782608695
# accuracy score corresponding to random state 83 is:  0.8641304347826086
# accuracy score corresponding to random state 84 is:  0.875
# accuracy score corresponding to random state 85 is:  0.8505434782608695
# accuracy score corresponding to random state 86 is:  0.8641304347826086
# accuracy score corresponding to random state 87 is:  0.8505434782608695
# accuracy score corresponding to random state 88 is:  0.8070652173913043
# accuracy score corresponding to random state 89 is:  0.8614130434782609
# accuracy score corresponding to random state 90 is:  0.845108695652174
# accuracy score corresponding to random state 91 is:  0.8614130434782609
# accuracy score corresponding to random state 92 is:  0.8532608695652174
# accuracy score corresponding to random state 93 is:  0.8858695652173914
# accuracy score corresponding to random state 94 is:  0.8288043478260869
# accuracy score corresponding to random state 95 is:  0.8559782608695652
# accuracy score corresponding to random state 96 is:  0.845108695652174
# accuracy score corresponding to random state 97 is:  0.842391304347826
# accuracy score corresponding to random state 98 is:  0.8478260869565217
# accuracy score corresponding to random state 99 is:  0.8505434782608695
# accuracy score corresponding to random state 100 is:  0.8125
#
#
# Max accuracy score corresponding to:  93 is:  0.8858695652173914
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
#
#
# for the algorithm:  SVC()
# accuracy score corresponding to random state 33 is:  0.8396739130434783
# accuracy score corresponding to random state 34 is:  0.8668478260869565
# accuracy score corresponding to random state 35 is:  0.8858695652173914
# accuracy score corresponding to random state 36 is:  0.8614130434782609
# accuracy score corresponding to random state 37 is:  0.8695652173913043
# accuracy score corresponding to random state 38 is:  0.8559782608695652
# accuracy score corresponding to random state 39 is:  0.8532608695652174
# accuracy score corresponding to random state 40 is:  0.8722826086956522
# accuracy score corresponding to random state 41 is:  0.8804347826086957
# accuracy score corresponding to random state 42 is:  0.8804347826086957
# accuracy score corresponding to random state 43 is:  0.8233695652173914
# accuracy score corresponding to random state 44 is:  0.8614130434782609
# accuracy score corresponding to random state 45 is:  0.842391304347826
# accuracy score corresponding to random state 46 is:  0.8315217391304348
# accuracy score corresponding to random state 47 is:  0.8586956521739131
# accuracy score corresponding to random state 48 is:  0.8668478260869565
# accuracy score corresponding to random state 49 is:  0.8478260869565217
# accuracy score corresponding to random state 50 is:  0.8478260869565217
# accuracy score corresponding to random state 51 is:  0.8505434782608695
# accuracy score corresponding to random state 52 is:  0.8668478260869565
# accuracy score corresponding to random state 53 is:  0.8641304347826086
# accuracy score corresponding to random state 54 is:  0.8478260869565217
# accuracy score corresponding to random state 55 is:  0.8858695652173914
# accuracy score corresponding to random state 56 is:  0.8532608695652174
# accuracy score corresponding to random state 57 is:  0.8668478260869565
# accuracy score corresponding to random state 58 is:  0.842391304347826
# accuracy score corresponding to random state 59 is:  0.8614130434782609
# accuracy score corresponding to random state 60 is:  0.8559782608695652
# accuracy score corresponding to random state 61 is:  0.8559782608695652
# accuracy score corresponding to random state 62 is:  0.8559782608695652
# accuracy score corresponding to random state 63 is:  0.8586956521739131
# accuracy score corresponding to random state 64 is:  0.8668478260869565
# accuracy score corresponding to random state 65 is:  0.8586956521739131
# accuracy score corresponding to random state 66 is:  0.8614130434782609
# accuracy score corresponding to random state 67 is:  0.8804347826086957
# accuracy score corresponding to random state 68 is:  0.8125
# accuracy score corresponding to random state 69 is:  0.8315217391304348
# accuracy score corresponding to random state 70 is:  0.8288043478260869
# accuracy score corresponding to random state 71 is:  0.8614130434782609
# accuracy score corresponding to random state 72 is:  0.8586956521739131
# accuracy score corresponding to random state 73 is:  0.8722826086956522
# accuracy score corresponding to random state 74 is:  0.8315217391304348
# accuracy score corresponding to random state 75 is:  0.8260869565217391
# accuracy score corresponding to random state 76 is:  0.845108695652174
# accuracy score corresponding to random state 77 is:  0.8614130434782609
# accuracy score corresponding to random state 78 is:  0.8831521739130435
# accuracy score corresponding to random state 79 is:  0.8152173913043478
# accuracy score corresponding to random state 80 is:  0.8505434782608695
# accuracy score corresponding to random state 81 is:  0.8614130434782609
# accuracy score corresponding to random state 82 is:  0.8559782608695652
# accuracy score corresponding to random state 83 is:  0.8695652173913043
# accuracy score corresponding to random state 84 is:  0.8586956521739131
# accuracy score corresponding to random state 85 is:  0.8668478260869565
# accuracy score corresponding to random state 86 is:  0.8722826086956522
# accuracy score corresponding to random state 87 is:  0.8559782608695652
# accuracy score corresponding to random state 88 is:  0.8369565217391305
# accuracy score corresponding to random state 89 is:  0.8396739130434783
# accuracy score corresponding to random state 90 is:  0.8614130434782609
# accuracy score corresponding to random state 91 is:  0.875
# accuracy score corresponding to random state 92 is:  0.8586956521739131
# accuracy score corresponding to random state 93 is:  0.8777173913043478
# accuracy score corresponding to random state 94 is:  0.8777173913043478
# accuracy score corresponding to random state 95 is:  0.845108695652174
# accuracy score corresponding to random state 96 is:  0.8342391304347826
# accuracy score corresponding to random state 97 is:  0.8315217391304348
# accuracy score corresponding to random state 98 is:  0.8586956521739131
# accuracy score corresponding to random state 99 is:  0.8586956521739131
# accuracy score corresponding to random state 100 is:  0.8668478260869565
#
#
# Max accuracy score corresponding to:  35 is:  0.8858695652173914
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
#
#
# for the algorithm:  DecisionTreeClassifier()
# accuracy score corresponding to random state 33 is:  0.7744565217391305
# accuracy score corresponding to random state 34 is:  0.7934782608695652
# accuracy score corresponding to random state 35 is:  0.782608695652174
# accuracy score corresponding to random state 36 is:  0.782608695652174
# accuracy score corresponding to random state 37 is:  0.7771739130434783
# accuracy score corresponding to random state 38 is:  0.7744565217391305
# accuracy score corresponding to random state 39 is:  0.8016304347826086
# accuracy score corresponding to random state 40 is:  0.7717391304347826
# accuracy score corresponding to random state 41 is:  0.7934782608695652
# accuracy score corresponding to random state 42 is:  0.7744565217391305
# accuracy score corresponding to random state 43 is:  0.7771739130434783
# accuracy score corresponding to random state 44 is:  0.7663043478260869
# accuracy score corresponding to random state 45 is:  0.7608695652173914
# accuracy score corresponding to random state 46 is:  0.7690217391304348
# accuracy score corresponding to random state 47 is:  0.8260869565217391
# accuracy score corresponding to random state 48 is:  0.8152173913043478
# accuracy score corresponding to random state 49 is:  0.7961956521739131
# accuracy score corresponding to random state 50 is:  0.7554347826086957
# accuracy score corresponding to random state 51 is:  0.7934782608695652
# accuracy score corresponding to random state 52 is:  0.7690217391304348
# accuracy score corresponding to random state 53 is:  0.8179347826086957
# accuracy score corresponding to random state 54 is:  0.8016304347826086
# accuracy score corresponding to random state 55 is:  0.7880434782608695
# accuracy score corresponding to random state 56 is:  0.7853260869565217
# accuracy score corresponding to random state 57 is:  0.8043478260869565
# accuracy score corresponding to random state 58 is:  0.7608695652173914
# accuracy score corresponding to random state 59 is:  0.7961956521739131
# accuracy score corresponding to random state 60 is:  0.7961956521739131
# accuracy score corresponding to random state 61 is:  0.7934782608695652
# accuracy score corresponding to random state 62 is:  0.8125
# accuracy score corresponding to random state 63 is:  0.7635869565217391
# accuracy score corresponding to random state 64 is:  0.8070652173913043
# accuracy score corresponding to random state 65 is:  0.7880434782608695
# accuracy score corresponding to random state 66 is:  0.7744565217391305
# accuracy score corresponding to random state 67 is:  0.7771739130434783
# accuracy score corresponding to random state 68 is:  0.7744565217391305
# accuracy score corresponding to random state 69 is:  0.7880434782608695
# accuracy score corresponding to random state 70 is:  0.7744565217391305
# accuracy score corresponding to random state 71 is:  0.7608695652173914
# accuracy score corresponding to random state 72 is:  0.782608695652174
# accuracy score corresponding to random state 73 is:  0.8097826086956522
# accuracy score corresponding to random state 74 is:  0.7961956521739131
# accuracy score corresponding to random state 75 is:  0.7663043478260869
# accuracy score corresponding to random state 76 is:  0.7880434782608695
# accuracy score corresponding to random state 77 is:  0.7663043478260869
# accuracy score corresponding to random state 78 is:  0.8016304347826086
# accuracy score corresponding to random state 79 is:  0.7690217391304348
# accuracy score corresponding to random state 80 is:  0.7989130434782609
# accuracy score corresponding to random state 81 is:  0.8070652173913043
# accuracy score corresponding to random state 82 is:  0.782608695652174
# accuracy score corresponding to random state 83 is:  0.7744565217391305
# accuracy score corresponding to random state 84 is:  0.8070652173913043
# accuracy score corresponding to random state 85 is:  0.782608695652174
# accuracy score corresponding to random state 86 is:  0.8315217391304348
# accuracy score corresponding to random state 87 is:  0.7853260869565217
# accuracy score corresponding to random state 88 is:  0.7880434782608695
# accuracy score corresponding to random state 89 is:  0.7771739130434783
# accuracy score corresponding to random state 90 is:  0.7771739130434783
# accuracy score corresponding to random state 91 is:  0.7771739130434783
# accuracy score corresponding to random state 92 is:  0.7744565217391305
# accuracy score corresponding to random state 93 is:  0.7527173913043478
# accuracy score corresponding to random state 94 is:  0.7989130434782609
# accuracy score corresponding to random state 95 is:  0.7527173913043478
# accuracy score corresponding to random state 96 is:  0.7554347826086957
# accuracy score corresponding to random state 97 is:  0.7771739130434783
# accuracy score corresponding to random state 98 is:  0.8125
# accuracy score corresponding to random state 99 is:  0.7336956521739131
# accuracy score corresponding to random state 100 is:  0.8016304347826086
#
#
# Max accuracy score corresponding to:  86 is:  0.8315217391304348
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦
#
#
# for the algorithm:  KNeighborsClassifier()
# accuracy score corresponding to random state 33 is:  0.8342391304347826
# accuracy score corresponding to random state 34 is:  0.8478260869565217
# accuracy score corresponding to random state 35 is:  0.8614130434782609
# accuracy score corresponding to random state 36 is:  0.8396739130434783
# accuracy score corresponding to random state 37 is:  0.8559782608695652
# accuracy score corresponding to random state 38 is:  0.8369565217391305
# accuracy score corresponding to random state 39 is:  0.8478260869565217
# accuracy score corresponding to random state 40 is:  0.845108695652174
# accuracy score corresponding to random state 41 is:  0.8668478260869565
# accuracy score corresponding to random state 42 is:  0.8532608695652174
# accuracy score corresponding to random state 43 is:  0.8125
# accuracy score corresponding to random state 44 is:  0.8559782608695652
# accuracy score corresponding to random state 45 is:  0.8288043478260869
# accuracy score corresponding to random state 46 is:  0.8179347826086957
# accuracy score corresponding to random state 47 is:  0.8315217391304348
# accuracy score corresponding to random state 48 is:  0.8396739130434783
# accuracy score corresponding to random state 49 is:  0.8288043478260869
# accuracy score corresponding to random state 50 is:  0.8396739130434783
# accuracy score corresponding to random state 51 is:  0.8478260869565217
# accuracy score corresponding to random state 52 is:  0.8396739130434783
# accuracy score corresponding to random state 53 is:  0.842391304347826
# accuracy score corresponding to random state 54 is:  0.8342391304347826
# accuracy score corresponding to random state 55 is:  0.8532608695652174
# accuracy score corresponding to random state 56 is:  0.8396739130434783
# accuracy score corresponding to random state 57 is:  0.842391304347826
# accuracy score corresponding to random state 58 is:  0.8233695652173914
# accuracy score corresponding to random state 59 is:  0.8532608695652174
# accuracy score corresponding to random state 60 is:  0.8206521739130435
# accuracy score corresponding to random state 61 is:  0.842391304347826
# accuracy score corresponding to random state 62 is:  0.8260869565217391
# accuracy score corresponding to random state 63 is:  0.8505434782608695
# accuracy score corresponding to random state 64 is:  0.8641304347826086
# accuracy score corresponding to random state 65 is:  0.8505434782608695
# accuracy score corresponding to random state 66 is:  0.845108695652174
# accuracy score corresponding to random state 67 is:  0.8668478260869565
# accuracy score corresponding to random state 68 is:  0.779891304347826
# accuracy score corresponding to random state 69 is:  0.8125
# accuracy score corresponding to random state 70 is:  0.8097826086956522
# accuracy score corresponding to random state 71 is:  0.845108695652174
# accuracy score corresponding to random state 72 is:  0.842391304347826
# accuracy score corresponding to random state 73 is:  0.8614130434782609
# accuracy score corresponding to random state 74 is:  0.8152173913043478
# accuracy score corresponding to random state 75 is:  0.7989130434782609
# accuracy score corresponding to random state 76 is:  0.8260869565217391
# accuracy score corresponding to random state 77 is:  0.8396739130434783
# accuracy score corresponding to random state 78 is:  0.8695652173913043
# accuracy score corresponding to random state 79 is:  0.8070652173913043
# accuracy score corresponding to random state 80 is:  0.8369565217391305
# accuracy score corresponding to random state 81 is:  0.8641304347826086
# accuracy score corresponding to random state 82 is:  0.8369565217391305
# accuracy score corresponding to random state 83 is:  0.8532608695652174
# accuracy score corresponding to random state 84 is:  0.8315217391304348
# accuracy score corresponding to random state 85 is:  0.8532608695652174
# accuracy score corresponding to random state 86 is:  0.8559782608695652
# accuracy score corresponding to random state 87 is:  0.845108695652174
# accuracy score corresponding to random state 88 is:  0.8260869565217391
# accuracy score corresponding to random state 89 is:  0.845108695652174
# accuracy score corresponding to random state 90 is:  0.8478260869565217
# accuracy score corresponding to random state 91 is:  0.8559782608695652
# accuracy score corresponding to random state 92 is:  0.8342391304347826
# accuracy score corresponding to random state 93 is:  0.8586956521739131
# accuracy score corresponding to random state 94 is:  0.8586956521739131
# accuracy score corresponding to random state 95 is:  0.8342391304347826
# accuracy score corresponding to random state 96 is:  0.8260869565217391
# accuracy score corresponding to random state 97 is:  0.8125
# accuracy score corresponding to random state 98 is:  0.8396739130434783
# accuracy score corresponding to random state 99 is:  0.845108695652174
# accuracy score corresponding to random state 100 is:  0.8369565217391305
#
#
# Max accuracy score corresponding to:  78 is:  0.8695652173913043
# ✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦✦

# %%
# Using grid searchCV

# %%
from sklearn.model_selection import GridSearchCV
lg=LogisticRegression()
parameters={ 'penalty':['l1','l2','elasticnet','none'],
           'multi_class':['auto','ovr','multinomial']}
cv=GridSearchCV(lg,parameters)
cv.fit(x,y)
cv.best_params_
# Out:
# {'multi_class': 'multinomial', 'penalty': 'l2'}

# %%
#Working with the best parameters of logistic Regression
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=40)
lgr=LogisticRegression(penalty='l2',multi_class='multinomial')
lgr.fit(x_train,y_train)
pred=lgr.predict(x_test)
print('Score of the model is: ',lgr.score(x_train,y_train))
print('Accuracy score: ',accuracy_score(pred,y_test))
print('confusion matrix: ',confusion_matrix(pred,y_test))
print('classification report: ',classification_report(pred,y_test))
# Out:
# Score of the model is:  0.8765880217785844
# Accuracy score:  0.904891304347826
# confusion matrix:  [[305  29]
#  [  6  28]]
# classification report:                precision    recall  f1-score   support
#
#            0       0.98      0.91      0.95       334
#            1       0.49      0.82      0.62        34
#
#     accuracy                           0.90       368
#    macro avg       0.74      0.87      0.78       368
# weighted avg       0.94      0.90      0.92       368

# %%
#Using adaboost to boost our model.
from sklearn.ensemble import AdaBoostClassifier
ada=AdaBoostClassifier(base_estimator=lgr,random_state=40)
ada.fit(x_train,y_train)
pred=ada.predict(x_test)
print('Score: ',ada.score(x_train,y_train))
print('Accuracy score: ',accuracy_score(pred,y_test))
print('Confusion matrix: ',confusion_matrix(pred,y_test))
print('classification report: ',classification_report(pred,y_test))
# Out:
# Score:  0.8702359346642469
# Accuracy score:  0.907608695652174
# Confusion matrix:  [[308  31]
#  [  3  26]]
# classification report:                precision    recall  f1-score   support
#
#            0       0.99      0.91      0.95       339
#            1       0.46      0.90      0.60        29
#
#     accuracy                           0.91       368
#    macro avg       0.72      0.90      0.78       368
# weighted avg       0.95      0.91      0.92       368

# %%
#Saving adaboost as it is enhancing the performance of the base estimator-LGR.
import joblib
joblib.dump(ada,'hr_attrition.pkl')
# Out:
# ['hr_attrition.pkl']

# %%
from sklearn.metrics import roc_curve,roc_auc_score

# %%
y_pred_prob=ada.predict_proba(x_test)[:,-1]
y_pred_prob
# Out:
# array([0.48958883, 0.49670464, 0.49134652, 0.50349274, 0.48197117,
#        0.47405851, 0.48951522, 0.48523819, 0.49003163, 0.49060395,
#        0.49156023, 0.49921964, 0.47961505, 0.50392084, 0.50659785,
#        0.48293186, 0.48265156, 0.50356345, 0.48369372, 0.4871748 ,
#        0.49190881, 0.49156391, 0.49945851, 0.48223901, 0.48560614,
#        0.48973106, 0.49910092, 0.48439137, 0.49708833, 0.48939948,
#        0.48739217, 0.47844493, 0.49476519, 0.48899712, 0.50151805,
#        0.50394496, 0.49206927, 0.48981349, 0.49014898, 0.48688739,
#        0.49172755, 0.48228719, 0.49051302, 0.49446503, 0.48502356,
#        0.48455645, 0.48591479, 0.49188106, 0.49617477, 0.48875568,
#        0.47680375, 0.47396032, 0.50247326, 0.49373174, 0.47876475,
#        0.49239509, 0.48338843, 0.48752093, 0.47323511, 0.48563813,
#        0.49694466, 0.48842355, 0.48505606, 0.48683737, 0.48884189,
#        0.48331902, 0.49494203, 0.48907764, 0.49317011, 0.48511447,
#        0.48586746, 0.49330923, 0.48763753, 0.49218221, 0.4838955 ,
#        0.492087  , 0.48528275, 0.48323659, 0.49578042, 0.49219646,
#        0.49456474, 0.50113684, 0.49265122, 0.49190953, 0.48434878,
#        0.48751613, 0.50387555, 0.50933799, 0.47165017, 0.48124008,
#        0.50206673, 0.48607424, 0.47801398, 0.49012472, 0.49331885,
#        0.48552634, 0.489897  , 0.47848485, 0.48513286, 0.49243339,
#        0.4841337 , 0.49148954, 0.50015348, 0.49514055, 0.48609222,
#        0.48889703, 0.49728103, 0.48336267, 0.48390695, 0.49873485,
#        0.48960363, 0.49432571, 0.50114927, 0.50617438, 0.48657201,
#        0.48523689, 0.48235158, 0.48745515, 0.49782967, 0.49410653,
#        0.50886984, 0.48561139, 0.49042498, 0.47847471, 0.48137901,
#        0.49254949, 0.49441309, 0.4795571 , 0.4980186 , 0.48127874,
#        0.48897867, 0.49232693, 0.49771988, 0.4884418 , 0.49489385,
#        0.4830482 , 0.47725604, 0.49829846, 0.48807354, 0.48403702,
#        0.49024614, 0.4966064 , 0.48738841, 0.48371552, 0.49302497,
#        0.48350833, 0.48527156, 0.48478336, 0.48922157, 0.47611716,
#        0.49409962, 0.49090332, 0.48825059, 0.49309599, 0.50401461,
#        0.48817093, 0.49765509, 0.48470103, 0.49755697, 0.48274827,
#        0.49073538, 0.48584942, 0.48855158, 0.48993531, 0.49549646,
#        0.48095834, 0.48474845, 0.48031866, 0.49623574, 0.49561538,
#        0.49599342, 0.49083411, 0.50224546, 0.49653599, 0.48861632,
#        0.49942038, 0.49768935, 0.48413586, 0.48919968, 0.49126626,
#        0.48717988, 0.4850682 , 0.48818954, 0.48574693, 0.49778473,
#        0.50086226, 0.48295186, 0.48202933, 0.48937507, 0.48185111,
#        0.48435795, 0.48992309, 0.49374644, 0.48339131, 0.48481757,
#        0.48112804, 0.48561624, 0.48354039, 0.49441206, 0.48337586,
#        0.48426187, 0.48416323, 0.49013181, 0.48540325, 0.47945523,
#        0.49336816, 0.49396634, 0.48994695, 0.48830038, 0.48293923,
#        0.48040531, 0.5069828 , 0.48089065, 0.49160246, 0.47588031,
#        0.48999587, 0.4791747 , 0.48828074, 0.48422482, 0.4876155 ,
#        0.50016244, 0.49850493, 0.48573906, 0.4965661 , 0.48618994,
#        0.50223184, 0.47531987, 0.48251892, 0.48833373, 0.49717092,
#        0.47985681, 0.49412314, 0.48626346, 0.49581102, 0.48688836,
#        0.48029869, 0.49522544, 0.4971567 , 0.49205331, 0.49568688,
#        0.48446427, 0.48962227, 0.4864752 , 0.48117721, 0.47996132,
#        0.48658462, 0.48362548, 0.49275949, 0.48922917, 0.48305895,
#        0.50213174, 0.49296773, 0.49682456, 0.48210026, 0.48192966,
#        0.47079871, 0.49120698, 0.48571993, 0.4979202 , 0.49054349,
#        0.49279149, 0.48109012, 0.47866309, 0.48426549, 0.48500101,
#        0.50015103, 0.48995348, 0.48388929, 0.50585936, 0.48375182,
#        0.49849547, 0.47262532, 0.49908934, 0.48826375, 0.4879408 ,
#        0.4885359 , 0.48532323, 0.48900524, 0.48354498, 0.48764583,
#        0.49439229, 0.4926427 , 0.49678804, 0.48824681, 0.49346828,
#        0.49062233, 0.49209222, 0.48872326, 0.48250663, 0.48970882,
#        0.47816015, 0.49231985, 0.50623163, 0.48499492, 0.48862249,
#        0.48488057, 0.47352033, 0.478476  , 0.4943158 , 0.49295612,
#        0.49681435, 0.49962796, 0.47192451, 0.48679751, 0.49191086,
#        0.49965271, 0.49014685, 0.48862215, 0.48651946, 0.4901634 ,
#        0.4787937 , 0.50245629, 0.48576058, 0.48802473, 0.49162848,
#        0.4898279 , 0.4961278 , 0.4858499 , 0.50328996, 0.48946791,
#        0.48972797, 0.4835703 , 0.48969695, 0.49216097, 0.4869514 ,
#        0.4823691 , 0.48816821, 0.48845164, 0.48828053, 0.49253879,
#        0.4881302 , 0.49625422, 0.48030642, 0.49122716, 0.49007449,
#        0.49767896, 0.48689187, 0.4941457 , 0.48651243, 0.49273153,
#        0.49398384, 0.48528875, 0.47805626, 0.48590645, 0.50199668,
#        0.49394243, 0.48685814, 0.48841066, 0.48898096, 0.48355507,
#        0.486873  , 0.48520782, 0.48689353, 0.49263566, 0.4965128 ,
#        0.48721895, 0.49257754, 0.47883317, 0.4957449 , 0.49819073,
#        0.49010032, 0.50431622, 0.48844357, 0.48938304, 0.49227549,
#        0.48255629, 0.48311539, 0.48847621])

# %%
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)

# %%
fpr
# Out:
# array([0.        , 0.        , 0.        , 0.00321543, 0.00321543,
#        0.00643087, 0.00643087, 0.0096463 , 0.0096463 , 0.02250804,
#        0.02250804, 0.02572347, 0.02572347, 0.03536977, 0.03536977,
#        0.03858521, 0.03858521, 0.05787781, 0.05787781, 0.06109325,
#        0.06109325, 0.07717042, 0.07717042, 0.08038585, 0.08038585,
#        0.08681672, 0.08681672, 0.15755627, 0.15755627, 0.18649518,
#        0.18649518, 0.19935691, 0.19935691, 0.20900322, 0.20900322,
#        0.23794212, 0.23794212, 0.28617363, 0.28617363, 0.31511254,
#        0.31511254, 0.35691318, 0.35691318, 0.36012862, 0.36012862,
#        0.45980707, 0.45980707, 0.49196141, 0.49196141, 0.52090032,
#        0.52090032, 0.53054662, 0.53054662, 0.64308682, 0.64308682,
#        0.80064309, 0.80064309, 0.97427653, 0.97427653, 1.        ,
#        1.        ])

# %%
tpr
# Out:
# array([0.        , 0.01754386, 0.12280702, 0.12280702, 0.24561404,
#        0.24561404, 0.38596491, 0.38596491, 0.45614035, 0.45614035,
#        0.49122807, 0.49122807, 0.52631579, 0.52631579, 0.54385965,
#        0.54385965, 0.56140351, 0.56140351, 0.57894737, 0.57894737,
#        0.59649123, 0.59649123, 0.61403509, 0.61403509, 0.63157895,
#        0.63157895, 0.64912281, 0.64912281, 0.70175439, 0.70175439,
#        0.71929825, 0.71929825, 0.73684211, 0.73684211, 0.75438596,
#        0.75438596, 0.77192982, 0.77192982, 0.78947368, 0.78947368,
#        0.80701754, 0.80701754, 0.8245614 , 0.8245614 , 0.84210526,
#        0.84210526, 0.85964912, 0.85964912, 0.87719298, 0.87719298,
#        0.89473684, 0.89473684, 0.9122807 , 0.9122807 , 0.94736842,
#        0.94736842, 0.96491228, 0.96491228, 0.98245614, 0.98245614,
#        1.        ])

# %%
thresholds
# Out:
# array([1.50933799, 0.50933799, 0.50585936, 0.50431622, 0.50328996,
#        0.50247326, 0.50114927, 0.50113684, 0.50015103, 0.49942038,
#        0.49910092, 0.49908934, 0.49850493, 0.49819073, 0.4980186 ,
#        0.4979202 , 0.49782967, 0.49755697, 0.49728103, 0.49717092,
#        0.4971567 , 0.49678804, 0.49670464, 0.4966064 , 0.4965661 ,
#        0.4965128 , 0.49625422, 0.4943158 , 0.49410653, 0.49331885,
#        0.49330923, 0.49296773, 0.49295612, 0.49273153, 0.49265122,
#        0.49231985, 0.49227549, 0.49156391, 0.49156023, 0.49062233,
#        0.49060395, 0.48999587, 0.48995348, 0.48994695, 0.48993531,
#        0.48861632, 0.48855158, 0.48828074, 0.48828053, 0.48802473,
#        0.4879408 , 0.4876155 , 0.48752093, 0.48563813, 0.48561139,
#        0.48337586, 0.48336267, 0.47611716, 0.47588031, 0.47165017,
#        0.47079871])

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='AdaBoostClassifier')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('AdaBoostClassifier')
plt.show()
